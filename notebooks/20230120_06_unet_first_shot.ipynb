# %% [markdown]
# ## In this notebook
#
# - Create U-net model.
# - Links:
#     - [U-Net Image Segmentation in Keras](https://pyimagesearch.com/2022/02/21/u-net-image-segmentation-in-keras/)
#     - [U-Net regression demo in Google Colab](https://colab.research.google.com/github/google/earthengine-api/blob/master/python/examples/ipynb/UNET_regression_demo.ipynb)
#     - [fnands/BioMassters_baseline](https://github.com/fnands/BioMassters_baseline/blob/main/unet_baseline.ipynb)

# %%
import os
import datetime
import time

# analytics
import pandas as pd
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
import numpy as np

# tif images processing
import tensorflow as tf
import tifffile as tiff
import matplotlib.pyplot as plt

# model
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OrdinalEncoder

from tensorflow.keras import layers
# Out:
# /opt/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ["[Errno 2] The file to load file system plugin from does not exist.: '/opt/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so'"]
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: cannot open shared object file: No such file or directory']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
FEATURES_METADATA_PROCESSED_FILEPATH = "../data/features_metadata_processed.csv"
FILTER_MONTH = "April"
SUBMISSION_FILES_CNT = 2_773
CHIPS_TO_SELECT_CNT = 100

# %% [markdown]
# ## Load metadata

# %%
df_metadata = pd.read_csv(FEATURES_METADATA_PROCESSED_FILEPATH)

# filter metadata
df_metadata = (
    df_metadata
    .loc[
        (df_metadata.month == FILTER_MONTH) &
        (df_metadata.split == "train")
    ]
    .reset_index(drop=True)
)

df_metadata.tail()
# Out:
#                  filename                                           filepath  \
# 17373  ffc7d4f2_S2_07.tif  /usr/src/app/data/train_features/ffc7d4f2_S2_0...
# 17374  ffd8db7a_S1_07.tif  /usr/src/app/data/train_features/ffd8db7a_S1_0...
# 17375  ffd8db7a_S2_07.tif  /usr/src/app/data/train_features/ffd8db7a_S2_0...
# 17376  fff05995_S1_07.tif  /usr/src/app/data/train_features/fff05995_S1_0...
# 17377  fff05995_S2_07.tif  /usr/src/app/data/train_features/fff05995_S2_0...
#
#           label_filename                                  label_filepath  \
# 17373  ffc7d4f2_agbm.tif  /usr/src/app/data/train_agbm/ffc7d4f2_agbm.tif
# 17374  ffd8db7a_agbm.tif  /usr/src/app/data/train_agbm/ffd8db7a_agbm.tif
# 17375  ffd8db7a_agbm.tif  /usr/src/app/data/train_agbm/ffd8db7a_agbm.tif
# 17376  fff05995_agbm.tif  /usr/src/app/data/train_agbm/fff05995_agbm.tif
# 17377  fff05995_agbm.tif  /usr/src/app/data/train_agbm/fff05995_agbm.tif
#
#         chip_id satellite  split  month
# 17373  ffc7d4f2        S2  train  April
# 17374  ffd8db7a        S1  train  April
# 17375  ffd8db7a        S2  train  April
# 17376  fff05995        S1  train  April
# 17377  fff05995        S2  train  April

# %% [markdown]
# ## Load data

# %%
# %%time

features = []
labels = []

for chip_id in np.random.choice(df_metadata.chip_id.unique(), size=CHIPS_TO_SELECT_CNT):
    
    # load data only from S2 satelite
    row = (
        df_metadata
        .loc[
            (df_metadata.chip_id == chip_id) & 
            (df_metadata.satellite == "S2")
        ]        
    )
    
    # load features
    filepath = row.filepath.values[0]
    features.append(
        tiff.imread(filepath)
    )
    
    # read labels
    label_filepath = row.label_filepath.values[0]
    labels.append(
        tiff.imread(label_filepath)
    )
    
    print(f"✅ Loaded chip with the following chip_id: {chip_id}")
# Out:
# ✅ Loaded chip with the following chip_id: f5077b99
# ✅ Loaded chip with the following chip_id: 0b0926dd
# ✅ Loaded chip with the following chip_id: 7085a844
# ✅ Loaded chip with the following chip_id: ac091b88
# ✅ Loaded chip with the following chip_id: c0d5cc9c
# ✅ Loaded chip with the following chip_id: 27a1ae34
# ✅ Loaded chip with the following chip_id: d201f5fa
# ✅ Loaded chip with the following chip_id: 210ff02e
# ✅ Loaded chip with the following chip_id: dff30b15
# ✅ Loaded chip with the following chip_id: 98bf873e
# ✅ Loaded chip with the following chip_id: addfdc9e
# ✅ Loaded chip with the following chip_id: 9a547ffb
# ✅ Loaded chip with the following chip_id: 92cc617d
# ✅ Loaded chip with the following chip_id: a74d5ce1
# ✅ Loaded chip with the following chip_id: 28fd5484
# ✅ Loaded chip with the following chip_id: 2940e282
# ✅ Loaded chip with the following chip_id: 863228a7
# ✅ Loaded chip with the following chip_id: a803d069
# ✅ Loaded chip with the following chip_id: 1b8c97f8
# ✅ Loaded chip with the following chip_id: e622c974
# ✅ Loaded chip with the following chip_id: c38bd02f
# ✅ Loaded chip with the following chip_id: d4dbf367
# ✅ Loaded chip with the following chip_id: 23d486b5
# ✅ Loaded chip with the following chip_id: 564e35fe
# ✅ Loaded chip with the following chip_id: f98760ce
# ✅ Loaded chip with the following chip_id: 55f08b33
# ✅ Loaded chip with the following chip_id: 2361b68d
# ✅ Loaded chip with the following chip_id: f5e3257b
# ✅ Loaded chip with the following chip_id: 03696b34
# ✅ Loaded chip with the following chip_id: d6b0c3c7
# ✅ Loaded chip with the following chip_id: 55342174
# ✅ Loaded chip with the following chip_id: 41873b53
# ✅ Loaded chip with the following chip_id: 10e402d8
# ✅ Loaded chip with the following chip_id: 8625b1a3
# ✅ Loaded chip with the following chip_id: b58d29c9
# ✅ Loaded chip with the following chip_id: 6bd4ca1e
# ✅ Loaded chip with the following chip_id: 7e7b6c33
# ✅ Loaded chip with the following chip_id: fad2cddd
# ✅ Loaded chip with the following chip_id: f8fd824a
# ✅ Loaded chip with the following chip_id: 28f02da2
# ✅ Loaded chip with the following chip_id: 9e860eda
# ✅ Loaded chip with the following chip_id: cb3a339f
# ✅ Loaded chip with the following chip_id: 547decc6
# ✅ Loaded chip with the following chip_id: e9e2a24f
# ✅ Loaded chip with the following chip_id: 690a2215
# ✅ Loaded chip with the following chip_id: 784d97f5
# ✅ Loaded chip with the following chip_id: 0c7ea7a7
# ✅ Loaded chip with the following chip_id: 939c4fcb
# ✅ Loaded chip with the following chip_id: d4061b6d
# ✅ Loaded chip with the following chip_id: 28162c0c
# ✅ Loaded chip with the following chip_id: 968d63a2
# ✅ Loaded chip with the following chip_id: b420511c
# ✅ Loaded chip with the following chip_id: 60f43e08
# ✅ Loaded chip with the following chip_id: 7a1593a5
# ✅ Loaded chip with the following chip_id: e4aae82c
# ✅ Loaded chip with the following chip_id: bb31b9b7
# ✅ Loaded chip with the following chip_id: c7687b82
# ✅ Loaded chip with the following chip_id: a292c83e
# ✅ Loaded chip with the following chip_id: bc3caaf9
# ✅ Loaded chip with the following chip_id: e79c7126
# ✅ Loaded chip with the following chip_id: e587db99
# ✅ Loaded chip with the following chip_id: 2a0ab392
# ✅ Loaded chip with the following chip_id: 63b5e2a5
# ✅ Loaded chip with the following chip_id: 764fee38
# ✅ Loaded chip with the following chip_id: cb3a339f
# ✅ Loaded chip with the following chip_id: 82f84fd6
# ✅ Loaded chip with the following chip_id: 49f00d7b
# ✅ Loaded chip with the following chip_id: 263cba48
# ✅ Loaded chip with the following chip_id: 1a7b9694
# ✅ Loaded chip with the following chip_id: f5077b99
# ✅ Loaded chip with the following chip_id: a22f4970
# ✅ Loaded chip with the following chip_id: c5177488
# ✅ Loaded chip with the following chip_id: 26834d19
# ✅ Loaded chip with the following chip_id: 2c577ff5
# ✅ Loaded chip with the following chip_id: 7e56ff2b
# ✅ Loaded chip with the following chip_id: 3ace6682
# ✅ Loaded chip with the following chip_id: 436a4440
# ✅ Loaded chip with the following chip_id: cb94b1c9
# ✅ Loaded chip with the following chip_id: 0b45f44d
# ✅ Loaded chip with the following chip_id: ca4d455b
# ✅ Loaded chip with the following chip_id: 99403896
# ✅ Loaded chip with the following chip_id: 867dd4db
# ✅ Loaded chip with the following chip_id: 8d98c0f3
# ✅ Loaded chip with the following chip_id: 5c24e281
# ✅ Loaded chip with the following chip_id: 9fbf65cf
# ✅ Loaded chip with the following chip_id: c2c04661
# ✅ Loaded chip with the following chip_id: f4125905
# ✅ Loaded chip with the following chip_id: bb968493
# ✅ Loaded chip with the following chip_id: 5979f8fc
# ✅ Loaded chip with the following chip_id: 98f30008
# ✅ Loaded chip with the following chip_id: c3771d47
# ✅ Loaded chip with the following chip_id: a3906a08
# ✅ Loaded chip with the following chip_id: 3ccb137d
# ✅ Loaded chip with the following chip_id: dc8efb60
# ✅ Loaded chip with the following chip_id: 9da1da09
# ✅ Loaded chip with the following chip_id: b83f5ceb
# ✅ Loaded chip with the following chip_id: 10c903e4
# ✅ Loaded chip with the following chip_id: 27b6c6d9
# ✅ Loaded chip with the following chip_id: 3282bfc0
# ✅ Loaded chip with the following chip_id: dc031753
# CPU times: user 487 ms, sys: 355 ms, total: 842 ms
# Wall time: 5.1 s

# %%
dataset = tf.data.Dataset.from_tensor_slices((features, labels))
print(dataset)
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(256, 256, 11), dtype=tf.uint16, name=None), TensorSpec(shape=(256, 256), dtype=tf.float32, name=None))>

# %%
BATCH_SIZE = 10
BUFFER_SIZE = 1000

# train_batches = train_dataset.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
# train_batches = train_batches.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
# validation_batches = test_dataset.take(3000).batch(BATCH_SIZE)
# test_batches = test_dataset.skip(3000).take(669).batch(BATCH_SIZE)

train_batches = (
    dataset
    .take(CHIPS_TO_SELECT_CNT - BATCH_SIZE)
    .cache()
    .batch(BATCH_SIZE)
    .repeat()
    .prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
)
test_batches = (
    dataset
    .skip(CHIPS_TO_SELECT_CNT - BATCH_SIZE)
    .take(BATCH_SIZE)
    .batch(BATCH_SIZE)
)

# %%
print(train_batches)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 11), dtype=tf.uint16, name=None), TensorSpec(shape=(None, 256, 256), dtype=tf.float32, name=None))>

# %%
def display(display_list):
    plt.figure(figsize=(15, 15))

    title = ["Input Image", "True Mask", "Predicted Mask"]

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(
            tf.transpose(display_list[i], perm=(2, 0, 1)).numpy()[3] # third band
            if i == 0 else display_list[i]
        )
        plt.axis("off")
    plt.show()

sample_batch = next(iter(train_batches))
random_index = np.random.choice(sample_batch[0].shape[0])
sample_image, sample_mask = sample_batch[0][random_index], sample_batch[1][random_index]
display([sample_image, sample_mask])
# Out:
# 2023-01-21 17:09:00.754572: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# ## Create model

# %%
def double_conv_block(x, n_filters):
    # Conv2D then ReLU activation
    x = layers.Conv2D(
        n_filters, 
        3, 
        padding="same", 
        activation="relu", 
        kernel_initializer="he_normal"
    )(x)
    
    # Conv2D then ReLU activation
    x = layers.Conv2D(
        n_filters, 
        3, 
        padding="same", 
        activation="relu", 
        kernel_initializer="he_normal"
    )(x)
    
    return x

# %%
def downsample_block(x, n_filters):
    f = double_conv_block(x, n_filters)
    p = layers.MaxPool2D(2)(f)
    p = layers.Dropout(0.3)(p)
    return f, p

# %%
def upsample_block(x, conv_features, n_filters):
    # upsample
    x = layers.Conv2DTranspose(
        n_filters, 
        3, 
        2, 
        padding="same"
    )(x)
    
    # concatenate
    x = layers.concatenate([x, conv_features])
    
    # dropout
    x = layers.Dropout(0.3)(x)
    
    # Conv2D twice with ReLU activation
    x = double_conv_block(x, n_filters)
    
    return x

# %%
def build_unet_model():
    # inputs
    inputs = layers.Input(shape=(256, 256, 11))

    # encoder: contracting path - downsample
    # 1 - downsample
    f1, p1 = downsample_block(inputs, 64)
    # 2 - downsample
    f2, p2 = downsample_block(p1, 128)
    # 3 - downsample
    f3, p3 = downsample_block(p2, 256)
    # 4 - downsample
    f4, p4 = downsample_block(p3, 512)

    # 5 - bottleneck
    bottleneck = double_conv_block(p4, 1024)

    # decoder: expanding path - upsample
    # 6 - upsample
    u6 = upsample_block(bottleneck, f4, 512)
    # 7 - upsample
    u7 = upsample_block(u6, f3, 256)
    # 8 - upsample
    u8 = upsample_block(u7, f2, 128)
    # 9 - upsample
    u9 = upsample_block(u8, f1, 64)

    # outputs
    # outputs = layers.Conv2D(256, 256, padding="same", activation="softmax")(u9)
    outputs = layers.Conv2D(1, 1, padding="same", activation="linear")(u9)

    # unet model with Keras Functional API
    unet_model = tf.keras.Model(inputs, outputs, name="U-Net")

    return unet_model

# %% [markdown]
# ## Train model

# %%
# compile model

unet_model = build_unet_model()

unet_model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    # loss="mse",
    # metrics="mse",
    
    loss="MeanSquaredError",
    metrics="RootMeanSquaredError",
)

# %%
# %%time

NUM_EPOCHS = 20
TRAIN_LENGTH = CHIPS_TO_SELECT_CNT - BATCH_SIZE
STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE
# VAL_SUBSPLITS = 5
# TEST_LENTH = info.splits["test"].num_examples
# VALIDATION_STEPS = TEST_LENTH // BATCH_SIZE // VAL_SUBSPLITS
VALIDATION_STEPS = 2

model_history = unet_model.fit(
    train_batches,
    epochs=NUM_EPOCHS,
    # steps_per_epoch=2,
    steps_per_epoch=STEPS_PER_EPOCH,
    # validation_steps=VALIDATION_STEPS,
    validation_data=test_batches,
    verbose=True,
)
# Out:
# Epoch 1/20
# 9/9 [==============================] - 88s 10s/step - loss: 133612872.0000 - root_mean_squared_error: 11559.1035 - val_loss: 661887.0000 - val_root_mean_squared_error: 813.5644
# Epoch 2/20
# 9/9 [==============================] - 86s 10s/step - loss: 743673.1875 - root_mean_squared_error: 862.3649 - val_loss: 113350.5156 - val_root_mean_squared_error: 336.6757
# Epoch 3/20
# 9/9 [==============================] - 86s 10s/step - loss: 229820.9062 - root_mean_squared_error: 479.3964 - val_loss: 22073.5039 - val_root_mean_squared_error: 148.5715
# Epoch 4/20
# 9/9 [==============================] - 86s 10s/step - loss: 126596.7578 - root_mean_squared_error: 355.8044 - val_loss: 20644.0215 - val_root_mean_squared_error: 143.6803
# Epoch 5/20
# 9/9 [==============================] - 86s 10s/step - loss: 77264.5703 - root_mean_squared_error: 277.9651 - val_loss: 9834.4795 - val_root_mean_squared_error: 99.1689
# Epoch 6/20
# 9/9 [==============================] - 85s 10s/step - loss: 47785.4766 - root_mean_squared_error: 218.5989 - val_loss: 9065.8643 - val_root_mean_squared_error: 95.2148
# Epoch 7/20
# 9/9 [==============================] - 86s 10s/step - loss: 32041.8574 - root_mean_squared_error: 179.0024 - val_loss: 8735.2734 - val_root_mean_squared_error: 93.4627
# Epoch 8/20
# 9/9 [==============================] - 86s 10s/step - loss: 23266.7285 - root_mean_squared_error: 152.5344 - val_loss: 9023.4043 - val_root_mean_squared_error: 94.9916
# Epoch 9/20
# 9/9 [==============================] - 85s 10s/step - loss: 16432.8867 - root_mean_squared_error: 128.1908 - val_loss: 8515.7969 - val_root_mean_squared_error: 92.2811
# Epoch 10/20
# 9/9 [==============================] - 86s 10s/step - loss: 11591.7988 - root_mean_squared_error: 107.6652 - val_loss: 8046.6260 - val_root_mean_squared_error: 89.7030
# Epoch 11/20
# 9/9 [==============================] - 86s 10s/step - loss: 8740.7031 - root_mean_squared_error: 93.4917 - val_loss: 6966.1592 - val_root_mean_squared_error: 83.4635
# Epoch 12/20
# 9/9 [==============================] - 86s 10s/step - loss: 6855.5425 - root_mean_squared_error: 82.7982 - val_loss: 6084.2607 - val_root_mean_squared_error: 78.0017
# Epoch 13/20
# 9/9 [==============================] - 86s 10s/step - loss: 5547.5117 - root_mean_squared_error: 74.4816 - val_loss: 5517.0889 - val_root_mean_squared_error: 74.2771
# Epoch 14/20
# 9/9 [==============================] - 86s 10s/step - loss: 4792.0205 - root_mean_squared_error: 69.2244 - val_loss: 4753.5337 - val_root_mean_squared_error: 68.9459
# Epoch 15/20
# 9/9 [==============================] - 85s 10s/step - loss: 4375.1533 - root_mean_squared_error: 66.1449 - val_loss: 4284.7593 - val_root_mean_squared_error: 65.4581
# Epoch 16/20
# 9/9 [==============================] - 86s 10s/step - loss: 4136.0400 - root_mean_squared_error: 64.3120 - val_loss: 4135.8486 - val_root_mean_squared_error: 64.3106
# Epoch 17/20
# 9/9 [==============================] - 89s 10s/step - loss: 4047.9819 - root_mean_squared_error: 63.6238 - val_loss: 4106.8086 - val_root_mean_squared_error: 64.0844
# Epoch 18/20
# 9/9 [==============================] - 87s 10s/step - loss: 4021.6145 - root_mean_squared_error: 63.4162 - val_loss: 4270.3237 - val_root_mean_squared_error: 65.3477
# Epoch 19/20
# 9/9 [==============================] - 89s 10s/step - loss: 4080.3618 - root_mean_squared_error: 63.8777 - val_loss: 4370.4087 - val_root_mean_squared_error: 66.1091
# Epoch 20/20
# 9/9 [==============================] - 87s 10s/step - loss: 4092.2195 - root_mean_squared_error: 63.9705 - val_loss: 4024.7280 - val_root_mean_squared_error: 63.4407
# CPU times: user 3h 26min 55s, sys: 11min 9s, total: 3h 38min 4s
# Wall time: 28min 46s

# %% [markdown]
# ## Check model results

# %%
ax = (
    pd.DataFrame({
        # "loss": model_history.history["loss"],
        # "val_loss": model_history.history["val_loss"], 
        "RMSE (train)": model_history.history["root_mean_squared_error"][7:],
        "RMSE (val)": model_history.history["val_root_mean_squared_error"][7:],
    })
    .plot(
        title="U-Net learning progress"
    )
)

ax.set_xlabel("Epoch")
ax.set_ylabel("RMSE")

plt.show()

# %%
test_results = unet_model.predict(
    test_batches
)

for res in test_results:
    plt.imshow(res)
    plt.show()
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
sample_batch = next(iter(test_batches))
random_index = np.random.choice(sample_batch[0].shape[0])
sample_image, sample_mask = sample_batch[0][random_index], sample_batch[1][random_index]
display([sample_image, sample_mask])

# %% [markdown]
# ## Create submission

# %%
df_metadata = pd.read_csv(FEATURES_METADATA_PROCESSED_FILEPATH)

# filter metadata
df_metadata = (
    df_metadata
    .loc[
        (df_metadata.month == "April") &
        (df_metadata.satellite == "S2") &
        (df_metadata.split == "test")
    ]
    .reset_index(drop=True)
)

# df_metadata["satellite_cnt_per_chip_month"] = (
#     df_metadata
#     .groupby(["chip_id", "month"])
#     .satellite
#     .transform("count")
# )

df_metadata.tail()
# Out:
#                 filename                                           filepath  \
# 2768  ff9dfc68_S2_07.tif  /usr/src/app/data/test_features/ff9dfc68_S2_07...
# 2769  ffda6cc9_S2_07.tif  /usr/src/app/data/test_features/ffda6cc9_S2_07...
# 2770  ffde1ed8_S2_07.tif  /usr/src/app/data/test_features/ffde1ed8_S2_07...
# 2771  ffdfa26a_S2_07.tif  /usr/src/app/data/test_features/ffdfa26a_S2_07...
# 2772  fff812c0_S2_07.tif  /usr/src/app/data/test_features/fff812c0_S2_07...
#
#          label_filename                                 label_filepath  \
# 2768  ff9dfc68_agbm.tif  /usr/src/app/data/test_agbm/ff9dfc68_agbm.tif
# 2769  ffda6cc9_agbm.tif  /usr/src/app/data/test_agbm/ffda6cc9_agbm.tif
# 2770  ffde1ed8_agbm.tif  /usr/src/app/data/test_agbm/ffde1ed8_agbm.tif
# 2771  ffdfa26a_agbm.tif  /usr/src/app/data/test_agbm/ffdfa26a_agbm.tif
# 2772  fff812c0_agbm.tif  /usr/src/app/data/test_agbm/fff812c0_agbm.tif
#
#        chip_id satellite split  month
# 2768  ff9dfc68        S2  test  April
# 2769  ffda6cc9        S2  test  April
# 2770  ffde1ed8        S2  test  April
# 2771  ffdfa26a        S2  test  April
# 2772  fff812c0        S2  test  April

# %%
# %%time

# predictions mean

for i, row in df_metadata.iterrows():
    
    # read filepath and label filepath
    filepath = row["filepath"]
    label_filepath = row["label_filepath"]
    
    pred = unet_model.predict(
        tiff.imread(filepath).reshape(1, 256, 256, 11),
        verbose=False,
    )
    
    # save predictions
    tiff.imwrite(
        label_filepath, 
        data=(
            pred[0]
            .reshape(256, 256)
            .astype(np.float32) 
        )
    )
    
    if (i % 100 == 0) & (i != 0):
        print(f"--> finished prediciton of {i:,} tifs")
# Out:
# --> finished prediciton of 100 tifs
# --> finished prediciton of 200 tifs
# --> finished prediciton of 300 tifs
# --> finished prediciton of 400 tifs
# --> finished prediciton of 500 tifs
# --> finished prediciton of 600 tifs
# --> finished prediciton of 700 tifs
# --> finished prediciton of 800 tifs
# --> finished prediciton of 900 tifs
# --> finished prediciton of 1,000 tifs
# --> finished prediciton of 1,100 tifs
# --> finished prediciton of 1,200 tifs
# --> finished prediciton of 1,300 tifs
# --> finished prediciton of 1,400 tifs
# --> finished prediciton of 1,500 tifs
# --> finished prediciton of 1,600 tifs
# --> finished prediciton of 1,700 tifs
# --> finished prediciton of 1,800 tifs
# --> finished prediciton of 1,900 tifs
# --> finished prediciton of 2,000 tifs
# --> finished prediciton of 2,100 tifs
# --> finished prediciton of 2,200 tifs
# --> finished prediciton of 2,300 tifs
# --> finished prediciton of 2,400 tifs
# --> finished prediciton of 2,500 tifs
# --> finished prediciton of 2,600 tifs
# --> finished prediciton of 2,700 tifs
# CPU times: user 1h 35min 49s, sys: 1min 34s, total: 1h 37min 24s
# Wall time: 17min 8s

# %% [markdown]
# ## Results
#
# - The following submissions have been made.
#     - Model 8 (U-net v1)
#         - Model has been trained on data subset (1 month, 90 chips per month).
#         - Model has been tested on 10 chips.
#         - Average RMSE equal to 58.5.
#
# *Yes, the results don't make very much the sense.*

# %% [markdown]
# ## TODO
#
# - Pokud je v 11. matici moc 255, např. více než 10 %, potom bych daný čip zahodil.
# - Normalizace hodnot.
# - Přidání S1 dat.
