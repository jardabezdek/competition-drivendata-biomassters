# %% [markdown]
# ## In this notebook
#
# - Create U-net model.
#     - With clouds.
#     - Normalized.
#     - More chips.
# - Links:
#     - [U-Net Image Segmentation in Keras](https://pyimagesearch.com/2022/02/21/u-net-image-segmentation-in-keras/)
#     - [U-Net regression demo in Google Colab](https://colab.research.google.com/github/google/earthengine-api/blob/master/python/examples/ipynb/UNET_regression_demo.ipynb)
#     - [fnands/BioMassters_baseline](https://github.com/fnands/BioMassters_baseline/blob/main/unet_baseline.ipynb)

# %%
import os
import datetime
import time

# analytics
import pandas as pd
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
import numpy as np

# tif images processing
import tensorflow as tf
import tifffile as tiff
import matplotlib.pyplot as plt

# model
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OrdinalEncoder

from tensorflow.keras import layers
# Out:
# /opt/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ["[Errno 2] The file to load file system plugin from does not exist.: '/opt/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so'"]
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/venv/lib/python3.8/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: cannot open shared object file: No such file or directory']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
FEATURES_METADATA_PROCESSED_FILEPATH = "../data/features_metadata_processed.csv"
FILTER_MONTH = "April"
SUBMISSION_FILES_CNT = 2_773
CHIPS_TO_SELECT_CNT = 1_000

# %% [markdown]
# ## Load metadata

# %%
df_metadata = pd.read_csv(FEATURES_METADATA_PROCESSED_FILEPATH)

# filter metadata
df_metadata = (
    df_metadata
    .loc[
        (df_metadata.month == FILTER_MONTH) &
        (df_metadata.split == "train")
    ]
    .reset_index(drop=True)
)

df_metadata.tail()
# Out:
#                  filename                                           filepath  \
# 17373  ffc7d4f2_S2_07.tif  /usr/src/app/data/train_features/ffc7d4f2_S2_0...
# 17374  ffd8db7a_S1_07.tif  /usr/src/app/data/train_features/ffd8db7a_S1_0...
# 17375  ffd8db7a_S2_07.tif  /usr/src/app/data/train_features/ffd8db7a_S2_0...
# 17376  fff05995_S1_07.tif  /usr/src/app/data/train_features/fff05995_S1_0...
# 17377  fff05995_S2_07.tif  /usr/src/app/data/train_features/fff05995_S2_0...
#
#           label_filename                                  label_filepath  \
# 17373  ffc7d4f2_agbm.tif  /usr/src/app/data/train_agbm/ffc7d4f2_agbm.tif
# 17374  ffd8db7a_agbm.tif  /usr/src/app/data/train_agbm/ffd8db7a_agbm.tif
# 17375  ffd8db7a_agbm.tif  /usr/src/app/data/train_agbm/ffd8db7a_agbm.tif
# 17376  fff05995_agbm.tif  /usr/src/app/data/train_agbm/fff05995_agbm.tif
# 17377  fff05995_agbm.tif  /usr/src/app/data/train_agbm/fff05995_agbm.tif
#
#         chip_id satellite  split  month
# 17373  ffc7d4f2        S2  train  April
# 17374  ffd8db7a        S1  train  April
# 17375  ffd8db7a        S2  train  April
# 17376  fff05995        S1  train  April
# 17377  fff05995        S2  train  April

# %% [markdown]
# ## Load data

# %%
def is_img_cloudy(filepath: str, clouds_threshold=0.1) -> bool:
    """Decide, if satelite image is cloudy."""
    cloud_probs = (
        tf
        .transpose(
            tiff.imread(filepath), 
            perm=(2, 0, 1)
        )
        .numpy()[10]
    )

    return np.mean(cloud_probs == 255) >= clouds_threshold

# %%
# %%time

features = []
labels = []
chips_cnt = 0

for chip_id in df_metadata.chip_id.unique():
    
    # load data only from S2 satelite
    row = (
        df_metadata
        .loc[
            (df_metadata.chip_id == chip_id) & 
            (df_metadata.satellite == "S2")
        ]        
    )
    
    # load features
    filepath = row.filepath.values[0]    
    features.append(
        tiff.imread(filepath)
    )
    
    # read labels
    label_filepath = row.label_filepath.values[0]
    labels.append(
        tiff.imread(label_filepath)
    )
    
    print(f"✅ Loaded chip with the following chip_id: {chip_id}")
    
    chips_cnt += 1
    if chips_cnt == CHIPS_TO_SELECT_CNT:
        break
# Out:
# ✅ Loaded chip with the following chip_id: 0003d2eb
# ✅ Loaded chip with the following chip_id: 000aa810
# ✅ Loaded chip with the following chip_id: 000d7e33
# ✅ Loaded chip with the following chip_id: 00184691
# ✅ Loaded chip with the following chip_id: 001b0634
# ✅ Loaded chip with the following chip_id: 001eb75a
# ✅ Loaded chip with the following chip_id: 0029317e
# ✅ Loaded chip with the following chip_id: 002fb84c
# ✅ Loaded chip with the following chip_id: 00301627
# ✅ Loaded chip with the following chip_id: 003a2b5b
# ✅ Loaded chip with the following chip_id: 003ab939
# ✅ Loaded chip with the following chip_id: 0040c3a8
# ✅ Loaded chip with the following chip_id: 004ef4ec
# ✅ Loaded chip with the following chip_id: 0058fedc
# ✅ Loaded chip with the following chip_id: 0060c0a5
# ✅ Loaded chip with the following chip_id: 00635116
# ✅ Loaded chip with the following chip_id: 0080ae28
# ✅ Loaded chip with the following chip_id: 0083efdf
# ✅ Loaded chip with the following chip_id: 008a52a9
# ✅ Loaded chip with the following chip_id: 008be628
# ✅ Loaded chip with the following chip_id: 008d48bf
# ✅ Loaded chip with the following chip_id: 009957ba
# ✅ Loaded chip with the following chip_id: 0099b501
# ✅ Loaded chip with the following chip_id: 00a0d9d4
# ✅ Loaded chip with the following chip_id: 00a0fcf3
# ✅ Loaded chip with the following chip_id: 00b7c361
# ✅ Loaded chip with the following chip_id: 00c03fbe
# ✅ Loaded chip with the following chip_id: 00cb4c3e
# ✅ Loaded chip with the following chip_id: 00d97746
# ✅ Loaded chip with the following chip_id: 00da2ec1
# ✅ Loaded chip with the following chip_id: 00de40a4
# ✅ Loaded chip with the following chip_id: 00e1d23f
# ✅ Loaded chip with the following chip_id: 00e6b793
# ✅ Loaded chip with the following chip_id: 00edfd51
# ✅ Loaded chip with the following chip_id: 00eee261
# ✅ Loaded chip with the following chip_id: 00efbedd
# ✅ Loaded chip with the following chip_id: 00f898a5
# ✅ Loaded chip with the following chip_id: 00fc19b1
# ✅ Loaded chip with the following chip_id: 00fd0698
# ✅ Loaded chip with the following chip_id: 00ff36dd
# ✅ Loaded chip with the following chip_id: 010966cb
# ✅ Loaded chip with the following chip_id: 011909e9
# ✅ Loaded chip with the following chip_id: 011bc55a
# ✅ Loaded chip with the following chip_id: 0131497d
# ✅ Loaded chip with the following chip_id: 0140e251
# ✅ Loaded chip with the following chip_id: 01417893
# ✅ Loaded chip with the following chip_id: 0147ad59
# ✅ Loaded chip with the following chip_id: 014e57fe
# ✅ Loaded chip with the following chip_id: 01503e8a
# ✅ Loaded chip with the following chip_id: 01567168
# ✅ Loaded chip with the following chip_id: 0157cf88
# ✅ Loaded chip with the following chip_id: 01583b0f
# ✅ Loaded chip with the following chip_id: 0177cc36
# ✅ Loaded chip with the following chip_id: 017f206b
# ✅ Loaded chip with the following chip_id: 01829c8b
# ✅ Loaded chip with the following chip_id: 018df98c
# ✅ Loaded chip with the following chip_id: 0193cab1
# ✅ Loaded chip with the following chip_id: 01a92708
# ✅ Loaded chip with the following chip_id: 01ac99fb
# ✅ Loaded chip with the following chip_id: 01b0ad1c
# ✅ Loaded chip with the following chip_id: 01b7f786
# ✅ Loaded chip with the following chip_id: 01bc24f4
# ✅ Loaded chip with the following chip_id: 01ccc4cf
# ✅ Loaded chip with the following chip_id: 01ce06f5
# ✅ Loaded chip with the following chip_id: 01e1a71e
# ✅ Loaded chip with the following chip_id: 01ea0701
# ✅ Loaded chip with the following chip_id: 01edae7b
# ✅ Loaded chip with the following chip_id: 01f1fef8
# ✅ Loaded chip with the following chip_id: 01f32968
# ✅ Loaded chip with the following chip_id: 01f7f810
# ✅ Loaded chip with the following chip_id: 01fb0167
# ✅ Loaded chip with the following chip_id: 01fec683
# ✅ Loaded chip with the following chip_id: 020aefcc
# ✅ Loaded chip with the following chip_id: 020c0e93
# ✅ Loaded chip with the following chip_id: 0215bd3a
# ✅ Loaded chip with the following chip_id: 02168744
# ✅ Loaded chip with the following chip_id: 021a5ed3
# ✅ Loaded chip with the following chip_id: 0226c804
# ✅ Loaded chip with the following chip_id: 0226fb18
# ✅ Loaded chip with the following chip_id: 022b4d29
# ✅ Loaded chip with the following chip_id: 02374617
# ✅ Loaded chip with the following chip_id: 023bff29
# ✅ Loaded chip with the following chip_id: 023f5e10
# ✅ Loaded chip with the following chip_id: 02400329
# ✅ Loaded chip with the following chip_id: 02546e15
# ✅ Loaded chip with the following chip_id: 025b36b1
# ✅ Loaded chip with the following chip_id: 02613007
# ✅ Loaded chip with the following chip_id: 026f95cb
# ✅ Loaded chip with the following chip_id: 02763d7a
# ✅ Loaded chip with the following chip_id: 027a4ff4
# ✅ Loaded chip with the following chip_id: 027d9c04
# ✅ Loaded chip with the following chip_id: 0287b450
# ✅ Loaded chip with the following chip_id: 0291ee27
# ✅ Loaded chip with the following chip_id: 02a1dc68
# ✅ Loaded chip with the following chip_id: 02a603ee
# ✅ Loaded chip with the following chip_id: 02a7f72f
# ✅ Loaded chip with the following chip_id: 02b4ce68
# ✅ Loaded chip with the following chip_id: 02c460be
# ✅ Loaded chip with the following chip_id: 02ceef52
# ✅ Loaded chip with the following chip_id: 02d8f406
# ✅ Loaded chip with the following chip_id: 02de88e0
# ✅ Loaded chip with the following chip_id: 02ea400e
# ✅ Loaded chip with the following chip_id: 02f46de1
# ✅ Loaded chip with the following chip_id: 02f855f0
# ✅ Loaded chip with the following chip_id: 02f894cc
# ✅ Loaded chip with the following chip_id: 02fd1e52
# ✅ Loaded chip with the following chip_id: 0300235a
# ✅ Loaded chip with the following chip_id: 030da7d1
# ✅ Loaded chip with the following chip_id: 031fd0f5
# ✅ Loaded chip with the following chip_id: 03224a52
# ✅ Loaded chip with the following chip_id: 032a9786
# ✅ Loaded chip with the following chip_id: 0331bda3
# ✅ Loaded chip with the following chip_id: 0332ebf4
# ✅ Loaded chip with the following chip_id: 03419529
# ✅ Loaded chip with the following chip_id: 034c753f
# ✅ Loaded chip with the following chip_id: 034d0cd4
# ✅ Loaded chip with the following chip_id: 035858c2
# ✅ Loaded chip with the following chip_id: 03660cb2
# ✅ Loaded chip with the following chip_id: 03696b34
# ✅ Loaded chip with the following chip_id: 036d94c9
# ✅ Loaded chip with the following chip_id: 0375894f
# ✅ Loaded chip with the following chip_id: 037a2db9
# ✅ Loaded chip with the following chip_id: 0384b13c
# ✅ Loaded chip with the following chip_id: 03862457
# ✅ Loaded chip with the following chip_id: 038a4e2b
# ✅ Loaded chip with the following chip_id: 038d0773
# ✅ Loaded chip with the following chip_id: 03adea0f
# ✅ Loaded chip with the following chip_id: 03b184cc
# ✅ Loaded chip with the following chip_id: 03b570e4
# ✅ Loaded chip with the following chip_id: 03b81185
# ✅ Loaded chip with the following chip_id: 03bd1b00
# ✅ Loaded chip with the following chip_id: 03bf29fa
# ✅ Loaded chip with the following chip_id: 03cfd5cd
# ✅ Loaded chip with the following chip_id: 03e506af
# ✅ Loaded chip with the following chip_id: 03f27ce1
# ✅ Loaded chip with the following chip_id: 03f9e229
# ✅ Loaded chip with the following chip_id: 04011347
# ✅ Loaded chip with the following chip_id: 040ad075
# ✅ Loaded chip with the following chip_id: 0410fc55
# ✅ Loaded chip with the following chip_id: 04203dc4
# ✅ Loaded chip with the following chip_id: 042c46f9
# ✅ Loaded chip with the following chip_id: 042dd93c
# ✅ Loaded chip with the following chip_id: 0436fc40
# ✅ Loaded chip with the following chip_id: 04392e0c
# ✅ Loaded chip with the following chip_id: 043d8d0c
# ✅ Loaded chip with the following chip_id: 04411212
# ✅ Loaded chip with the following chip_id: 04447492
# ✅ Loaded chip with the following chip_id: 044fe27e
# ✅ Loaded chip with the following chip_id: 04719c15
# ✅ Loaded chip with the following chip_id: 04850701
# ✅ Loaded chip with the following chip_id: 04869e3c
# ✅ Loaded chip with the following chip_id: 048a3f5f
# ✅ Loaded chip with the following chip_id: 0493d777
# ✅ Loaded chip with the following chip_id: 04a6a767
# ✅ Loaded chip with the following chip_id: 04b380c7
# ✅ Loaded chip with the following chip_id: 04b6efc5
# ✅ Loaded chip with the following chip_id: 04b7d503
# ✅ Loaded chip with the following chip_id: 04ca83f0
# ✅ Loaded chip with the following chip_id: 04d55e6a
# ✅ Loaded chip with the following chip_id: 04dad591
# ✅ Loaded chip with the following chip_id: 04dbc732
# ✅ Loaded chip with the following chip_id: 04dd4f3b
# ✅ Loaded chip with the following chip_id: 04debe47
# ✅ Loaded chip with the following chip_id: 04e9d006
# ✅ Loaded chip with the following chip_id: 050649cc
# ✅ Loaded chip with the following chip_id: 051dc280
# ✅ Loaded chip with the following chip_id: 05232d1e
# ✅ Loaded chip with the following chip_id: 0529a3e8
# ✅ Loaded chip with the following chip_id: 052d6e62
# ✅ Loaded chip with the following chip_id: 0532076d
# ✅ Loaded chip with the following chip_id: 053aa3da
# ✅ Loaded chip with the following chip_id: 053facf0
# ✅ Loaded chip with the following chip_id: 05405d08
# ✅ Loaded chip with the following chip_id: 0546ac0a
# ✅ Loaded chip with the following chip_id: 05476041
# ✅ Loaded chip with the following chip_id: 0548c792
# ✅ Loaded chip with the following chip_id: 0548f884
# ✅ Loaded chip with the following chip_id: 054d4908
# ✅ Loaded chip with the following chip_id: 054de818
# ✅ Loaded chip with the following chip_id: 056224a2
# ✅ Loaded chip with the following chip_id: 0564f89d
# ✅ Loaded chip with the following chip_id: 05681655
# ✅ Loaded chip with the following chip_id: 057088b1
# ✅ Loaded chip with the following chip_id: 0571b175
# ✅ Loaded chip with the following chip_id: 057ebe07
# ✅ Loaded chip with the following chip_id: 05a903fb
# ✅ Loaded chip with the following chip_id: 05b0083d
# ✅ Loaded chip with the following chip_id: 05b643ec
# ✅ Loaded chip with the following chip_id: 05b9612e
# ✅ Loaded chip with the following chip_id: 05c35f7f
# ✅ Loaded chip with the following chip_id: 05cb0ff2
# ✅ Loaded chip with the following chip_id: 05d31b5c
# ✅ Loaded chip with the following chip_id: 05e52522
# ✅ Loaded chip with the following chip_id: 05fb3175
# ✅ Loaded chip with the following chip_id: 05fd5ad1
# ✅ Loaded chip with the following chip_id: 0600f14b
# ✅ Loaded chip with the following chip_id: 06056511
# ✅ Loaded chip with the following chip_id: 0610fc19
# ✅ Loaded chip with the following chip_id: 06137b43
# ✅ Loaded chip with the following chip_id: 06158185
# ✅ Loaded chip with the following chip_id: 061637a0
# ✅ Loaded chip with the following chip_id: 061c4601
# ✅ Loaded chip with the following chip_id: 0620ddb2
# ✅ Loaded chip with the following chip_id: 06212e56
# ✅ Loaded chip with the following chip_id: 0625a02b
# ✅ Loaded chip with the following chip_id: 062b353e
# ✅ Loaded chip with the following chip_id: 0636b264
# ✅ Loaded chip with the following chip_id: 06479ab2
# ✅ Loaded chip with the following chip_id: 06483cd7
# ✅ Loaded chip with the following chip_id: 0651d43e
# ✅ Loaded chip with the following chip_id: 065520d3
# ✅ Loaded chip with the following chip_id: 0655e85d
# ✅ Loaded chip with the following chip_id: 0658093b
# ✅ Loaded chip with the following chip_id: 065d3bd8
# ✅ Loaded chip with the following chip_id: 065e3a97
# ✅ Loaded chip with the following chip_id: 06643e05
# ✅ Loaded chip with the following chip_id: 066b0311
# ✅ Loaded chip with the following chip_id: 067248a3
# ✅ Loaded chip with the following chip_id: 0676eb5d
# ✅ Loaded chip with the following chip_id: 0678c538
# ✅ Loaded chip with the following chip_id: 06843249
# ✅ Loaded chip with the following chip_id: 068e2563
# ✅ Loaded chip with the following chip_id: 06917114
# ✅ Loaded chip with the following chip_id: 0693e0a4
# ✅ Loaded chip with the following chip_id: 06b1fc3a
# ✅ Loaded chip with the following chip_id: 06b41dfc
# ✅ Loaded chip with the following chip_id: 06df3742
# ✅ Loaded chip with the following chip_id: 06e3d6af
# ✅ Loaded chip with the following chip_id: 06e891e5
# ✅ Loaded chip with the following chip_id: 06f112dd
# ✅ Loaded chip with the following chip_id: 06fc9487
# ✅ Loaded chip with the following chip_id: 071b57b1
# ✅ Loaded chip with the following chip_id: 071dc8a5
# ✅ Loaded chip with the following chip_id: 0729ea67
# ✅ Loaded chip with the following chip_id: 07378cde
# ✅ Loaded chip with the following chip_id: 073fb3e5
# ✅ Loaded chip with the following chip_id: 0751323a
# ✅ Loaded chip with the following chip_id: 07580a94
# ✅ Loaded chip with the following chip_id: 0761c4f1
# ✅ Loaded chip with the following chip_id: 07677e7e
# ✅ Loaded chip with the following chip_id: 076abd46
# ✅ Loaded chip with the following chip_id: 07741cb0
# ✅ Loaded chip with the following chip_id: 07765e15
# ✅ Loaded chip with the following chip_id: 077eaf9a
# ✅ Loaded chip with the following chip_id: 0781e3ed
# ✅ Loaded chip with the following chip_id: 0787865c
# ✅ Loaded chip with the following chip_id: 078ec944
# ✅ Loaded chip with the following chip_id: 07973811
# ✅ Loaded chip with the following chip_id: 07a084ca
# ✅ Loaded chip with the following chip_id: 07b9823a
# ✅ Loaded chip with the following chip_id: 07bcc6d6
# ✅ Loaded chip with the following chip_id: 07d1864c
# ✅ Loaded chip with the following chip_id: 07d6e963
# ✅ Loaded chip with the following chip_id: 07e3ec27
# ✅ Loaded chip with the following chip_id: 07ebc1f7
# ✅ Loaded chip with the following chip_id: 07f11c88
# ✅ Loaded chip with the following chip_id: 07f3cd5e
# ✅ Loaded chip with the following chip_id: 07f9f6a4
# ✅ Loaded chip with the following chip_id: 08084efe
# ✅ Loaded chip with the following chip_id: 080d8f1d
# ✅ Loaded chip with the following chip_id: 080ed0c5
# ✅ Loaded chip with the following chip_id: 080fb169
# ✅ Loaded chip with the following chip_id: 08103218
# ✅ Loaded chip with the following chip_id: 0817358a
# ✅ Loaded chip with the following chip_id: 0823f904
# ✅ Loaded chip with the following chip_id: 08251bb9
# ✅ Loaded chip with the following chip_id: 082cce42
# ✅ Loaded chip with the following chip_id: 0836d4c7
# ✅ Loaded chip with the following chip_id: 083a02c7
# ✅ Loaded chip with the following chip_id: 083f0dfb
# ✅ Loaded chip with the following chip_id: 08404854
# ✅ Loaded chip with the following chip_id: 084a44a0
# ✅ Loaded chip with the following chip_id: 085fcb0f
# ✅ Loaded chip with the following chip_id: 08676196
# ✅ Loaded chip with the following chip_id: 08686874
# ✅ Loaded chip with the following chip_id: 086c47df
# ✅ Loaded chip with the following chip_id: 086d7d16
# ✅ Loaded chip with the following chip_id: 088cd6f2
# ✅ Loaded chip with the following chip_id: 088dd40f
# ✅ Loaded chip with the following chip_id: 088e7b1a
# ✅ Loaded chip with the following chip_id: 089c5af4
# ✅ Loaded chip with the following chip_id: 08a18d5c
# ✅ Loaded chip with the following chip_id: 08a4dfe0
# ✅ Loaded chip with the following chip_id: 08a643d6
# ✅ Loaded chip with the following chip_id: 08a806a7
# ✅ Loaded chip with the following chip_id: 08c83160
# ✅ Loaded chip with the following chip_id: 08e0ff94
# ✅ Loaded chip with the following chip_id: 08ecfd3c
# ✅ Loaded chip with the following chip_id: 08f6b400
# ✅ Loaded chip with the following chip_id: 08f8e396
# ✅ Loaded chip with the following chip_id: 08ff8dd3
# ✅ Loaded chip with the following chip_id: 090636b0
# ✅ Loaded chip with the following chip_id: 090cec45
# ✅ Loaded chip with the following chip_id: 09171a70
# ✅ Loaded chip with the following chip_id: 09188771
# ✅ Loaded chip with the following chip_id: 09203898
# ✅ Loaded chip with the following chip_id: 0921957f
# ✅ Loaded chip with the following chip_id: 0929e279
# ✅ Loaded chip with the following chip_id: 092ce360
# ✅ Loaded chip with the following chip_id: 093a11a8
# ✅ Loaded chip with the following chip_id: 093a9e24
# ✅ Loaded chip with the following chip_id: 094567e5
# ✅ Loaded chip with the following chip_id: 0950a3da
# ✅ Loaded chip with the following chip_id: 095979c0
# ✅ Loaded chip with the following chip_id: 095cdde6
# ✅ Loaded chip with the following chip_id: 095d9117
# ✅ Loaded chip with the following chip_id: 0964800b
# ✅ Loaded chip with the following chip_id: 0979f778
# ✅ Loaded chip with the following chip_id: 097d3257
# ✅ Loaded chip with the following chip_id: 0980ecf3
# ✅ Loaded chip with the following chip_id: 09816493
# ✅ Loaded chip with the following chip_id: 0983a0f7
# ✅ Loaded chip with the following chip_id: 09914ef8
# ✅ Loaded chip with the following chip_id: 099191b9
# ✅ Loaded chip with the following chip_id: 09974f8c
# ✅ Loaded chip with the following chip_id: 099c6b3b
# ✅ Loaded chip with the following chip_id: 099e1a11
# ✅ Loaded chip with the following chip_id: 09a2cc22
# ✅ Loaded chip with the following chip_id: 09a30b35
# ✅ Loaded chip with the following chip_id: 09a84ecc
# ✅ Loaded chip with the following chip_id: 09a8596e
# ✅ Loaded chip with the following chip_id: 09cf24b5
# ✅ Loaded chip with the following chip_id: 09d20656
# ✅ Loaded chip with the following chip_id: 09dd7b70
# ✅ Loaded chip with the following chip_id: 09dde789
# ✅ Loaded chip with the following chip_id: 09e13567
# ✅ Loaded chip with the following chip_id: 09e36dd8
# ✅ Loaded chip with the following chip_id: 09e9ac7f
# ✅ Loaded chip with the following chip_id: 09f19109
# ✅ Loaded chip with the following chip_id: 09fd6d1a
# ✅ Loaded chip with the following chip_id: 0a04e5c1
# ✅ Loaded chip with the following chip_id: 0a073fe4
# ✅ Loaded chip with the following chip_id: 0a096068
# ✅ Loaded chip with the following chip_id: 0a105fce
# ✅ Loaded chip with the following chip_id: 0a132a88
# ✅ Loaded chip with the following chip_id: 0a35ad65
# ✅ Loaded chip with the following chip_id: 0a35b443
# ✅ Loaded chip with the following chip_id: 0a39dd9e
# ✅ Loaded chip with the following chip_id: 0a3d8f03
# ✅ Loaded chip with the following chip_id: 0a3faec0
# ✅ Loaded chip with the following chip_id: 0a58ac70
# ✅ Loaded chip with the following chip_id: 0a5fa091
# ✅ Loaded chip with the following chip_id: 0a65fa3f
# ✅ Loaded chip with the following chip_id: 0a676e24
# ✅ Loaded chip with the following chip_id: 0a684a97
# ✅ Loaded chip with the following chip_id: 0a6bc33f
# ✅ Loaded chip with the following chip_id: 0a781cab
# ✅ Loaded chip with the following chip_id: 0a81b559
# ✅ Loaded chip with the following chip_id: 0a81cdee
# ✅ Loaded chip with the following chip_id: 0a8b6998
# ✅ Loaded chip with the following chip_id: 0a9d13a4
# ✅ Loaded chip with the following chip_id: 0aa21699
# ✅ Loaded chip with the following chip_id: 0aa7fb10
# ✅ Loaded chip with the following chip_id: 0aac1e46
# ✅ Loaded chip with the following chip_id: 0ab097c9
# ✅ Loaded chip with the following chip_id: 0ac443da
# ✅ Loaded chip with the following chip_id: 0acc54b4
# ✅ Loaded chip with the following chip_id: 0acd8a27
# ✅ Loaded chip with the following chip_id: 0ad475a1
# ✅ Loaded chip with the following chip_id: 0ad57788
# ✅ Loaded chip with the following chip_id: 0ad655e2
# ✅ Loaded chip with the following chip_id: 0adf9e66
# ✅ Loaded chip with the following chip_id: 0ae6324a
# ✅ Loaded chip with the following chip_id: 0b0926dd
# ✅ Loaded chip with the following chip_id: 0b0eec49
# ✅ Loaded chip with the following chip_id: 0b255824
# ✅ Loaded chip with the following chip_id: 0b2c3886
# ✅ Loaded chip with the following chip_id: 0b30548f
# ✅ Loaded chip with the following chip_id: 0b3349ff
# ✅ Loaded chip with the following chip_id: 0b353ba8
# ✅ Loaded chip with the following chip_id: 0b36d307
# ✅ Loaded chip with the following chip_id: 0b45f44d
# ✅ Loaded chip with the following chip_id: 0b485d3b
# ✅ Loaded chip with the following chip_id: 0b5dd5d0
# ✅ Loaded chip with the following chip_id: 0b5de22d
# ✅ Loaded chip with the following chip_id: 0b6ae2b1
# ✅ Loaded chip with the following chip_id: 0b6f6d40
# ✅ Loaded chip with the following chip_id: 0b792613
# ✅ Loaded chip with the following chip_id: 0b8d5875
# ✅ Loaded chip with the following chip_id: 0ba2a063
# ✅ Loaded chip with the following chip_id: 0ba31a2c
# ✅ Loaded chip with the following chip_id: 0ba7bca7
# ✅ Loaded chip with the following chip_id: 0baa5577
# ✅ Loaded chip with the following chip_id: 0bac0847
# ✅ Loaded chip with the following chip_id: 0badc5ba
# ✅ Loaded chip with the following chip_id: 0bc9709a
# ✅ Loaded chip with the following chip_id: 0bc9b53c
# ✅ Loaded chip with the following chip_id: 0bdba623
# ✅ Loaded chip with the following chip_id: 0bde3a29
# ✅ Loaded chip with the following chip_id: 0be278ec
# ✅ Loaded chip with the following chip_id: 0bf069c3
# ✅ Loaded chip with the following chip_id: 0bf46883
# ✅ Loaded chip with the following chip_id: 0bf98345
# ✅ Loaded chip with the following chip_id: 0bfa0434
# ✅ Loaded chip with the following chip_id: 0c03fb03
# ✅ Loaded chip with the following chip_id: 0c0b40d3
# ✅ Loaded chip with the following chip_id: 0c13c720
# ✅ Loaded chip with the following chip_id: 0c19b4a5
# ✅ Loaded chip with the following chip_id: 0c1b5ede
# ✅ Loaded chip with the following chip_id: 0c1dea12
# ✅ Loaded chip with the following chip_id: 0c1e1474
# ✅ Loaded chip with the following chip_id: 0c258ba6
# ✅ Loaded chip with the following chip_id: 0c2af57b
# ✅ Loaded chip with the following chip_id: 0c340511
# ✅ Loaded chip with the following chip_id: 0c48b873
# ✅ Loaded chip with the following chip_id: 0c4a3582
# ✅ Loaded chip with the following chip_id: 0c4aafbf
# ✅ Loaded chip with the following chip_id: 0c4f11f0
# ✅ Loaded chip with the following chip_id: 0c65a284
# ✅ Loaded chip with the following chip_id: 0c6dc601
# ✅ Loaded chip with the following chip_id: 0c7ea7a7
# ✅ Loaded chip with the following chip_id: 0c9539fe
# ✅ Loaded chip with the following chip_id: 0c9d78ab
# ✅ Loaded chip with the following chip_id: 0ca16dfd
# ✅ Loaded chip with the following chip_id: 0ca69c96
# ✅ Loaded chip with the following chip_id: 0cb01158
# ✅ Loaded chip with the following chip_id: 0cc46779
# ✅ Loaded chip with the following chip_id: 0cc4de55
# ✅ Loaded chip with the following chip_id: 0cd8ffb5
# ✅ Loaded chip with the following chip_id: 0cda02ad
# ✅ Loaded chip with the following chip_id: 0cdb980d
# ✅ Loaded chip with the following chip_id: 0cdd0050
# ✅ Loaded chip with the following chip_id: 0d0be2c8
# ✅ Loaded chip with the following chip_id: 0d109e74
# ✅ Loaded chip with the following chip_id: 0d129e66
# ✅ Loaded chip with the following chip_id: 0d1c68af
# ✅ Loaded chip with the following chip_id: 0d226508
# ✅ Loaded chip with the following chip_id: 0d29f58c
# ✅ Loaded chip with the following chip_id: 0d2b5776
# ✅ Loaded chip with the following chip_id: 0d37cb5f
# ✅ Loaded chip with the following chip_id: 0d40d2ba
# ✅ Loaded chip with the following chip_id: 0d43e377
# ✅ Loaded chip with the following chip_id: 0d445fb6
# ✅ Loaded chip with the following chip_id: 0d46f24a
# ✅ Loaded chip with the following chip_id: 0d4b9de6
# ✅ Loaded chip with the following chip_id: 0d4bbc1a
# ✅ Loaded chip with the following chip_id: 0d5bc776
# ✅ Loaded chip with the following chip_id: 0d665376
# ✅ Loaded chip with the following chip_id: 0d68af9c
# ✅ Loaded chip with the following chip_id: 0d694ba9
# ✅ Loaded chip with the following chip_id: 0d710330
# ✅ Loaded chip with the following chip_id: 0d820bc7
# ✅ Loaded chip with the following chip_id: 0d8e3338
# ✅ Loaded chip with the following chip_id: 0d90aa12
# ✅ Loaded chip with the following chip_id: 0d93826f
# ✅ Loaded chip with the following chip_id: 0d9bc03c
# ✅ Loaded chip with the following chip_id: 0d9d5ac6
# ✅ Loaded chip with the following chip_id: 0dbe745e
# ✅ Loaded chip with the following chip_id: 0dc14cfd
# ✅ Loaded chip with the following chip_id: 0dc5a9b3
# ✅ Loaded chip with the following chip_id: 0dd2d6c9
# ✅ Loaded chip with the following chip_id: 0dd93df8
# ✅ Loaded chip with the following chip_id: 0ddd95d2
# ✅ Loaded chip with the following chip_id: 0de178b7
# ✅ Loaded chip with the following chip_id: 0de54a5e
# ✅ Loaded chip with the following chip_id: 0e04c0c7
# ✅ Loaded chip with the following chip_id: 0e081ce3
# ✅ Loaded chip with the following chip_id: 0e0dfb3b
# ✅ Loaded chip with the following chip_id: 0e174295
# ✅ Loaded chip with the following chip_id: 0e19de83
# ✅ Loaded chip with the following chip_id: 0e1b75bc
# ✅ Loaded chip with the following chip_id: 0e21d97c
# ✅ Loaded chip with the following chip_id: 0e2f6368
# ✅ Loaded chip with the following chip_id: 0e50ca04
# ✅ Loaded chip with the following chip_id: 0e5fff30
# ✅ Loaded chip with the following chip_id: 0e67339f
# ✅ Loaded chip with the following chip_id: 0e67ed1e
# ✅ Loaded chip with the following chip_id: 0e6911dd
# ✅ Loaded chip with the following chip_id: 0e6cd7a8
# ✅ Loaded chip with the following chip_id: 0e74f3ca
# ✅ Loaded chip with the following chip_id: 0e826cd4
# ✅ Loaded chip with the following chip_id: 0e82ba8f
# ✅ Loaded chip with the following chip_id: 0e83c7fe
# ✅ Loaded chip with the following chip_id: 0e8b2ac7
# ✅ Loaded chip with the following chip_id: 0e8efa76
# ✅ Loaded chip with the following chip_id: 0e8f061c
# ✅ Loaded chip with the following chip_id: 0e92cd13
# ✅ Loaded chip with the following chip_id: 0e95dc51
# ✅ Loaded chip with the following chip_id: 0ea3ff4c
# ✅ Loaded chip with the following chip_id: 0ea789a8
# ✅ Loaded chip with the following chip_id: 0eaa6bdf
# ✅ Loaded chip with the following chip_id: 0eb18cbe
# ✅ Loaded chip with the following chip_id: 0ebea80a
# ✅ Loaded chip with the following chip_id: 0ebf5d45
# ✅ Loaded chip with the following chip_id: 0ebf6765
# ✅ Loaded chip with the following chip_id: 0ec976dc
# ✅ Loaded chip with the following chip_id: 0ecb75df
# ✅ Loaded chip with the following chip_id: 0ecc9585
# ✅ Loaded chip with the following chip_id: 0ed6856a
# ✅ Loaded chip with the following chip_id: 0ee6ad89
# ✅ Loaded chip with the following chip_id: 0ef7b574
# ✅ Loaded chip with the following chip_id: 0efa5c94
# ✅ Loaded chip with the following chip_id: 0f07f1d0
# ✅ Loaded chip with the following chip_id: 0f08c93b
# ✅ Loaded chip with the following chip_id: 0f0a493a
# ✅ Loaded chip with the following chip_id: 0f119d95
# ✅ Loaded chip with the following chip_id: 0f123dad
# ✅ Loaded chip with the following chip_id: 0f24e6a8
# ✅ Loaded chip with the following chip_id: 0f26a281
# ✅ Loaded chip with the following chip_id: 0f26e952
# ✅ Loaded chip with the following chip_id: 0f28166a
# ✅ Loaded chip with the following chip_id: 0f3dfa71
# ✅ Loaded chip with the following chip_id: 0f478b85
# ✅ Loaded chip with the following chip_id: 0f54b847
# ✅ Loaded chip with the following chip_id: 0f5a4563
# ✅ Loaded chip with the following chip_id: 0f5d3266
# ✅ Loaded chip with the following chip_id: 0f663c46
# ✅ Loaded chip with the following chip_id: 0f687c36
# ✅ Loaded chip with the following chip_id: 0f6faf05
# ✅ Loaded chip with the following chip_id: 0f705e95
# ✅ Loaded chip with the following chip_id: 0f709309
# ✅ Loaded chip with the following chip_id: 0f75684e
# ✅ Loaded chip with the following chip_id: 0f77b53e
# ✅ Loaded chip with the following chip_id: 0f8a4733
# ✅ Loaded chip with the following chip_id: 0f8f5c4e
# ✅ Loaded chip with the following chip_id: 0f908375
# ✅ Loaded chip with the following chip_id: 0f941205
# ✅ Loaded chip with the following chip_id: 0f967a67
# ✅ Loaded chip with the following chip_id: 0f97ca13
# ✅ Loaded chip with the following chip_id: 0f9cf58a
# ✅ Loaded chip with the following chip_id: 0fa196fb
# ✅ Loaded chip with the following chip_id: 0fa1f946
# ✅ Loaded chip with the following chip_id: 0fae8d98
# ✅ Loaded chip with the following chip_id: 0fba70be
# ✅ Loaded chip with the following chip_id: 0fbaeaed
# ✅ Loaded chip with the following chip_id: 0fbff89f
# ✅ Loaded chip with the following chip_id: 0fc676e7
# ✅ Loaded chip with the following chip_id: 0fc70cb9
# ✅ Loaded chip with the following chip_id: 0fcf82e4
# ✅ Loaded chip with the following chip_id: 0fd2954e
# ✅ Loaded chip with the following chip_id: 0fd644ae
# ✅ Loaded chip with the following chip_id: 0fd7b6dd
# ✅ Loaded chip with the following chip_id: 0fdb9f77
# ✅ Loaded chip with the following chip_id: 0fdd733f
# ✅ Loaded chip with the following chip_id: 0fde7165
# ✅ Loaded chip with the following chip_id: 0feabc85
# ✅ Loaded chip with the following chip_id: 0fef27ce
# ✅ Loaded chip with the following chip_id: 0ff268b1
# ✅ Loaded chip with the following chip_id: 0ffaa79e
# ✅ Loaded chip with the following chip_id: 100c9e0c
# ✅ Loaded chip with the following chip_id: 10148836
# ✅ Loaded chip with the following chip_id: 1022440a
# ✅ Loaded chip with the following chip_id: 1023cbd6
# ✅ Loaded chip with the following chip_id: 10339b8e
# ✅ Loaded chip with the following chip_id: 10429d71
# ✅ Loaded chip with the following chip_id: 10519639
# ✅ Loaded chip with the following chip_id: 1088bebb
# ✅ Loaded chip with the following chip_id: 108f49f3
# ✅ Loaded chip with the following chip_id: 109117ef
# ✅ Loaded chip with the following chip_id: 109560c3
# ✅ Loaded chip with the following chip_id: 109add1e
# ✅ Loaded chip with the following chip_id: 109be0f6
# ✅ Loaded chip with the following chip_id: 10a07ed0
# ✅ Loaded chip with the following chip_id: 10a179b8
# ✅ Loaded chip with the following chip_id: 10aec4e9
# ✅ Loaded chip with the following chip_id: 10b290d1
# ✅ Loaded chip with the following chip_id: 10b2e090
# ✅ Loaded chip with the following chip_id: 10b7aa9a
# ✅ Loaded chip with the following chip_id: 10bca2b9
# ✅ Loaded chip with the following chip_id: 10c4a409
# ✅ Loaded chip with the following chip_id: 10c4a551
# ✅ Loaded chip with the following chip_id: 10c903e4
# ✅ Loaded chip with the following chip_id: 10cddd46
# ✅ Loaded chip with the following chip_id: 10d8338c
# ✅ Loaded chip with the following chip_id: 10dd7864
# ✅ Loaded chip with the following chip_id: 10ddceda
# ✅ Loaded chip with the following chip_id: 10e2ac42
# ✅ Loaded chip with the following chip_id: 10e402d8
# ✅ Loaded chip with the following chip_id: 10e8d157
# ✅ Loaded chip with the following chip_id: 10eb4b3e
# ✅ Loaded chip with the following chip_id: 10fcf382
# ✅ Loaded chip with the following chip_id: 11082fab
# ✅ Loaded chip with the following chip_id: 1116e6fa
# ✅ Loaded chip with the following chip_id: 1117109a
# ✅ Loaded chip with the following chip_id: 1121c294
# ✅ Loaded chip with the following chip_id: 11220d4c
# ✅ Loaded chip with the following chip_id: 1141c57b
# ✅ Loaded chip with the following chip_id: 1145aa56
# ✅ Loaded chip with the following chip_id: 114cdf32
# ✅ Loaded chip with the following chip_id: 114ce554
# ✅ Loaded chip with the following chip_id: 115ae9a0
# ✅ Loaded chip with the following chip_id: 115ff5d8
# ✅ Loaded chip with the following chip_id: 11679ec2
# ✅ Loaded chip with the following chip_id: 11684502
# ✅ Loaded chip with the following chip_id: 116917f1
# ✅ Loaded chip with the following chip_id: 116e9d64
# ✅ Loaded chip with the following chip_id: 117b670a
# ✅ Loaded chip with the following chip_id: 1194d9b8
# ✅ Loaded chip with the following chip_id: 1199f6fa
# ✅ Loaded chip with the following chip_id: 11a05bb0
# ✅ Loaded chip with the following chip_id: 11acb23f
# ✅ Loaded chip with the following chip_id: 11b305f0
# ✅ Loaded chip with the following chip_id: 11b99653
# ✅ Loaded chip with the following chip_id: 11c945aa
# ✅ Loaded chip with the following chip_id: 11db9e19
# ✅ Loaded chip with the following chip_id: 11dfb643
# ✅ Loaded chip with the following chip_id: 11e4de70
# ✅ Loaded chip with the following chip_id: 11fc4d5f
# ✅ Loaded chip with the following chip_id: 11fe604f
# ✅ Loaded chip with the following chip_id: 11feb2e5
# ✅ Loaded chip with the following chip_id: 1210a461
# ✅ Loaded chip with the following chip_id: 121f6463
# ✅ Loaded chip with the following chip_id: 12224d5f
# ✅ Loaded chip with the following chip_id: 122ef21e
# ✅ Loaded chip with the following chip_id: 123067b1
# ✅ Loaded chip with the following chip_id: 1232b976
# ✅ Loaded chip with the following chip_id: 124f631a
# ✅ Loaded chip with the following chip_id: 1250c93f
# ✅ Loaded chip with the following chip_id: 1252f4d7
# ✅ Loaded chip with the following chip_id: 12534830
# ✅ Loaded chip with the following chip_id: 1259d0a9
# ✅ Loaded chip with the following chip_id: 125b32ae
# ✅ Loaded chip with the following chip_id: 128287c0
# ✅ Loaded chip with the following chip_id: 128adae8
# ✅ Loaded chip with the following chip_id: 128eb2aa
# ✅ Loaded chip with the following chip_id: 1291713b
# ✅ Loaded chip with the following chip_id: 12a71535
# ✅ Loaded chip with the following chip_id: 12b8cf9c
# ✅ Loaded chip with the following chip_id: 12c02d4b
# ✅ Loaded chip with the following chip_id: 12cc0324
# ✅ Loaded chip with the following chip_id: 12d4474f
# ✅ Loaded chip with the following chip_id: 12d58dcc
# ✅ Loaded chip with the following chip_id: 12d934e3
# ✅ Loaded chip with the following chip_id: 12e972b8
# ✅ Loaded chip with the following chip_id: 12ed637a
# ✅ Loaded chip with the following chip_id: 12f74127
# ✅ Loaded chip with the following chip_id: 12fb5503
# ✅ Loaded chip with the following chip_id: 12fd7631
# ✅ Loaded chip with the following chip_id: 1307a04a
# ✅ Loaded chip with the following chip_id: 131806e4
# ✅ Loaded chip with the following chip_id: 131c9c06
# ✅ Loaded chip with the following chip_id: 1324f4d5
# ✅ Loaded chip with the following chip_id: 132590e4
# ✅ Loaded chip with the following chip_id: 13263137
# ✅ Loaded chip with the following chip_id: 13389308
# ✅ Loaded chip with the following chip_id: 134430e4
# ✅ Loaded chip with the following chip_id: 13444622
# ✅ Loaded chip with the following chip_id: 1348d51a
# ✅ Loaded chip with the following chip_id: 135027e8
# ✅ Loaded chip with the following chip_id: 1355dfaa
# ✅ Loaded chip with the following chip_id: 135da382
# ✅ Loaded chip with the following chip_id: 136423b2
# ✅ Loaded chip with the following chip_id: 136af50d
# ✅ Loaded chip with the following chip_id: 136e2139
# ✅ Loaded chip with the following chip_id: 137884a2
# ✅ Loaded chip with the following chip_id: 1379a8c4
# ✅ Loaded chip with the following chip_id: 137c96c6
# ✅ Loaded chip with the following chip_id: 137eb3f7
# ✅ Loaded chip with the following chip_id: 1380e8f4
# ✅ Loaded chip with the following chip_id: 1385fc6b
# ✅ Loaded chip with the following chip_id: 13892357
# ✅ Loaded chip with the following chip_id: 138bc232
# ✅ Loaded chip with the following chip_id: 1398c186
# ✅ Loaded chip with the following chip_id: 13a080c9
# ✅ Loaded chip with the following chip_id: 13a24a0e
# ✅ Loaded chip with the following chip_id: 13b3308d
# ✅ Loaded chip with the following chip_id: 13c3cd1e
# ✅ Loaded chip with the following chip_id: 13cc8832
# ✅ Loaded chip with the following chip_id: 13cf35fa
# ✅ Loaded chip with the following chip_id: 13e8c3a5
# ✅ Loaded chip with the following chip_id: 13f5a73e
# ✅ Loaded chip with the following chip_id: 13fc1f56
# ✅ Loaded chip with the following chip_id: 13fc84d8
# ✅ Loaded chip with the following chip_id: 1410e147
# ✅ Loaded chip with the following chip_id: 1417b0a6
# ✅ Loaded chip with the following chip_id: 14279b82
# ✅ Loaded chip with the following chip_id: 1436fa9d
# ✅ Loaded chip with the following chip_id: 14397bfb
# ✅ Loaded chip with the following chip_id: 1446b274
# ✅ Loaded chip with the following chip_id: 144e144c
# ✅ Loaded chip with the following chip_id: 145d0600
# ✅ Loaded chip with the following chip_id: 1460c6b1
# ✅ Loaded chip with the following chip_id: 14633304
# ✅ Loaded chip with the following chip_id: 146c7d5c
# ✅ Loaded chip with the following chip_id: 1475c48e
# ✅ Loaded chip with the following chip_id: 147c9028
# ✅ Loaded chip with the following chip_id: 1481964f
# ✅ Loaded chip with the following chip_id: 1481ee37
# ✅ Loaded chip with the following chip_id: 14888ef2
# ✅ Loaded chip with the following chip_id: 1490037d
# ✅ Loaded chip with the following chip_id: 149f144d
# ✅ Loaded chip with the following chip_id: 14ba8aab
# ✅ Loaded chip with the following chip_id: 14cd6946
# ✅ Loaded chip with the following chip_id: 14cf1ec4
# ✅ Loaded chip with the following chip_id: 14d3b92b
# ✅ Loaded chip with the following chip_id: 14db0101
# ✅ Loaded chip with the following chip_id: 14e2540f
# ✅ Loaded chip with the following chip_id: 14fe1473
# ✅ Loaded chip with the following chip_id: 150299cf
# ✅ Loaded chip with the following chip_id: 150695ef
# ✅ Loaded chip with the following chip_id: 150b249d
# ✅ Loaded chip with the following chip_id: 1510e9cd
# ✅ Loaded chip with the following chip_id: 1511cb4d
# ✅ Loaded chip with the following chip_id: 15154fa6
# ✅ Loaded chip with the following chip_id: 151cf430
# ✅ Loaded chip with the following chip_id: 153a51b7
# ✅ Loaded chip with the following chip_id: 153fb447
# ✅ Loaded chip with the following chip_id: 1541e9dc
# ✅ Loaded chip with the following chip_id: 1541fb61
# ✅ Loaded chip with the following chip_id: 1549f396
# ✅ Loaded chip with the following chip_id: 15524a1f
# ✅ Loaded chip with the following chip_id: 1556ffec
# ✅ Loaded chip with the following chip_id: 155fbfd7
# ✅ Loaded chip with the following chip_id: 15623d55
# ✅ Loaded chip with the following chip_id: 1567ab76
# ✅ Loaded chip with the following chip_id: 1569b4e2
# ✅ Loaded chip with the following chip_id: 156a36c8
# ✅ Loaded chip with the following chip_id: 156a6a96
# ✅ Loaded chip with the following chip_id: 157158e8
# ✅ Loaded chip with the following chip_id: 15728cd4
# ✅ Loaded chip with the following chip_id: 1580dc60
# ✅ Loaded chip with the following chip_id: 159a09be
# ✅ Loaded chip with the following chip_id: 159a4fce
# ✅ Loaded chip with the following chip_id: 15ab3b9a
# ✅ Loaded chip with the following chip_id: 15b23ce1
# ✅ Loaded chip with the following chip_id: 15bc6b41
# ✅ Loaded chip with the following chip_id: 15bf4479
# ✅ Loaded chip with the following chip_id: 15c7876b
# ✅ Loaded chip with the following chip_id: 15ca148b
# ✅ Loaded chip with the following chip_id: 15d03d91
# ✅ Loaded chip with the following chip_id: 15e2454a
# ✅ Loaded chip with the following chip_id: 15e43b1c
# ✅ Loaded chip with the following chip_id: 15e8a734
# ✅ Loaded chip with the following chip_id: 15f686c8
# ✅ Loaded chip with the following chip_id: 15fbfeff
# ✅ Loaded chip with the following chip_id: 15ff0c73
# ✅ Loaded chip with the following chip_id: 161ca1ea
# ✅ Loaded chip with the following chip_id: 1628fba4
# ✅ Loaded chip with the following chip_id: 162bdc23
# ✅ Loaded chip with the following chip_id: 163ae886
# ✅ Loaded chip with the following chip_id: 163e6988
# ✅ Loaded chip with the following chip_id: 1648a27a
# ✅ Loaded chip with the following chip_id: 1657fc67
# ✅ Loaded chip with the following chip_id: 166078d6
# ✅ Loaded chip with the following chip_id: 16635583
# ✅ Loaded chip with the following chip_id: 166be7d7
# ✅ Loaded chip with the following chip_id: 16709fa3
# ✅ Loaded chip with the following chip_id: 168d2687
# ✅ Loaded chip with the following chip_id: 169059e0
# ✅ Loaded chip with the following chip_id: 1693843f
# ✅ Loaded chip with the following chip_id: 1693bbe7
# ✅ Loaded chip with the following chip_id: 16999324
# ✅ Loaded chip with the following chip_id: 16a87337
# ✅ Loaded chip with the following chip_id: 16afe4a7
# ✅ Loaded chip with the following chip_id: 16b80308
# ✅ Loaded chip with the following chip_id: 16c09f38
# ✅ Loaded chip with the following chip_id: 16c80351
# ✅ Loaded chip with the following chip_id: 16d8cac6
# ✅ Loaded chip with the following chip_id: 16db3af7
# ✅ Loaded chip with the following chip_id: 16df9dc7
# ✅ Loaded chip with the following chip_id: 16f624b6
# ✅ Loaded chip with the following chip_id: 16fc7acc
# ✅ Loaded chip with the following chip_id: 17058554
# ✅ Loaded chip with the following chip_id: 1718f00d
# ✅ Loaded chip with the following chip_id: 171caf70
# ✅ Loaded chip with the following chip_id: 1727ff76
# ✅ Loaded chip with the following chip_id: 173902ba
# ✅ Loaded chip with the following chip_id: 173f6c91
# ✅ Loaded chip with the following chip_id: 17432244
# ✅ Loaded chip with the following chip_id: 1746b831
# ✅ Loaded chip with the following chip_id: 174ca2b3
# ✅ Loaded chip with the following chip_id: 17512095
# ✅ Loaded chip with the following chip_id: 1753a3b1
# ✅ Loaded chip with the following chip_id: 1756103d
# ✅ Loaded chip with the following chip_id: 175c2e5e
# ✅ Loaded chip with the following chip_id: 176e5ab2
# ✅ Loaded chip with the following chip_id: 177a7af9
# ✅ Loaded chip with the following chip_id: 177bab49
# ✅ Loaded chip with the following chip_id: 177ce4ba
# ✅ Loaded chip with the following chip_id: 179095b6
# ✅ Loaded chip with the following chip_id: 17912870
# ✅ Loaded chip with the following chip_id: 17912e75
# ✅ Loaded chip with the following chip_id: 179460ce
# ✅ Loaded chip with the following chip_id: 179cfc99
# ✅ Loaded chip with the following chip_id: 179eedaa
# ✅ Loaded chip with the following chip_id: 17a40ea5
# ✅ Loaded chip with the following chip_id: 17ad734b
# ✅ Loaded chip with the following chip_id: 17b83678
# ✅ Loaded chip with the following chip_id: 17c2a733
# ✅ Loaded chip with the following chip_id: 17c3913b
# ✅ Loaded chip with the following chip_id: 17d0234d
# ✅ Loaded chip with the following chip_id: 17d0eeb0
# ✅ Loaded chip with the following chip_id: 17de67d1
# ✅ Loaded chip with the following chip_id: 17e8e8be
# ✅ Loaded chip with the following chip_id: 17eb4d69
# ✅ Loaded chip with the following chip_id: 17f54050
# ✅ Loaded chip with the following chip_id: 17fd0184
# ✅ Loaded chip with the following chip_id: 180eef35
# ✅ Loaded chip with the following chip_id: 1811929e
# ✅ Loaded chip with the following chip_id: 1816d18d
# ✅ Loaded chip with the following chip_id: 1820f58c
# ✅ Loaded chip with the following chip_id: 18233e50
# ✅ Loaded chip with the following chip_id: 182b00e9
# ✅ Loaded chip with the following chip_id: 1834b1fc
# ✅ Loaded chip with the following chip_id: 183a0b6c
# ✅ Loaded chip with the following chip_id: 183ee57b
# ✅ Loaded chip with the following chip_id: 1848af90
# ✅ Loaded chip with the following chip_id: 1856baeb
# ✅ Loaded chip with the following chip_id: 18595b6b
# ✅ Loaded chip with the following chip_id: 18694516
# ✅ Loaded chip with the following chip_id: 186a1895
# ✅ Loaded chip with the following chip_id: 186c990c
# ✅ Loaded chip with the following chip_id: 186ddf71
# ✅ Loaded chip with the following chip_id: 1876694c
# ✅ Loaded chip with the following chip_id: 187cf18b
# ✅ Loaded chip with the following chip_id: 188772ab
# ✅ Loaded chip with the following chip_id: 18a96bec
# ✅ Loaded chip with the following chip_id: 18ab8a17
# ✅ Loaded chip with the following chip_id: 18d3b697
# ✅ Loaded chip with the following chip_id: 18d952b3
# ✅ Loaded chip with the following chip_id: 18ef433e
# ✅ Loaded chip with the following chip_id: 18f1047f
# ✅ Loaded chip with the following chip_id: 1904d828
# ✅ Loaded chip with the following chip_id: 190974c2
# ✅ Loaded chip with the following chip_id: 190bb25c
# ✅ Loaded chip with the following chip_id: 19149c65
# ✅ Loaded chip with the following chip_id: 19204d6f
# ✅ Loaded chip with the following chip_id: 1925f7d8
# ✅ Loaded chip with the following chip_id: 192eb2e0
# ✅ Loaded chip with the following chip_id: 193364a3
# ✅ Loaded chip with the following chip_id: 19339797
# ✅ Loaded chip with the following chip_id: 19354358
# ✅ Loaded chip with the following chip_id: 1936f8a5
# ✅ Loaded chip with the following chip_id: 19385711
# ✅ Loaded chip with the following chip_id: 193d4a66
# ✅ Loaded chip with the following chip_id: 1942f772
# ✅ Loaded chip with the following chip_id: 194366ae
# ✅ Loaded chip with the following chip_id: 19457017
# ✅ Loaded chip with the following chip_id: 194f6b2f
# ✅ Loaded chip with the following chip_id: 195487ec
# ✅ Loaded chip with the following chip_id: 196298ea
# ✅ Loaded chip with the following chip_id: 196c199c
# ✅ Loaded chip with the following chip_id: 19720e70
# ✅ Loaded chip with the following chip_id: 197e48d0
# ✅ Loaded chip with the following chip_id: 19842835
# ✅ Loaded chip with the following chip_id: 1987c5e7
# ✅ Loaded chip with the following chip_id: 1990d8e4
# ✅ Loaded chip with the following chip_id: 1993b36e
# ✅ Loaded chip with the following chip_id: 19a0fe11
# ✅ Loaded chip with the following chip_id: 19aa0cc6
# ✅ Loaded chip with the following chip_id: 19ae04fe
# ✅ Loaded chip with the following chip_id: 19bdd036
# ✅ Loaded chip with the following chip_id: 19c50fe1
# ✅ Loaded chip with the following chip_id: 19ca3adf
# ✅ Loaded chip with the following chip_id: 19ccf803
# ✅ Loaded chip with the following chip_id: 19d7cbd4
# ✅ Loaded chip with the following chip_id: 19da9e8f
# ✅ Loaded chip with the following chip_id: 19e57ad4
# ✅ Loaded chip with the following chip_id: 19e5e877
# ✅ Loaded chip with the following chip_id: 19e8e599
# ✅ Loaded chip with the following chip_id: 19ea29be
# ✅ Loaded chip with the following chip_id: 19fd52db
# ✅ Loaded chip with the following chip_id: 1a00c008
# ✅ Loaded chip with the following chip_id: 1a01514c
# ✅ Loaded chip with the following chip_id: 1a1addd1
# ✅ Loaded chip with the following chip_id: 1a1f591d
# ✅ Loaded chip with the following chip_id: 1a2e7791
# ✅ Loaded chip with the following chip_id: 1a346c55
# ✅ Loaded chip with the following chip_id: 1a5fcd05
# ✅ Loaded chip with the following chip_id: 1a65b34b
# ✅ Loaded chip with the following chip_id: 1a6df311
# ✅ Loaded chip with the following chip_id: 1a7b9694
# ✅ Loaded chip with the following chip_id: 1a7ddc2a
# ✅ Loaded chip with the following chip_id: 1a7ff67a
# ✅ Loaded chip with the following chip_id: 1a8b952f
# ✅ Loaded chip with the following chip_id: 1a9adc0a
# ✅ Loaded chip with the following chip_id: 1a9e2daa
# ✅ Loaded chip with the following chip_id: 1aa3f35a
# ✅ Loaded chip with the following chip_id: 1aab2ea9
# ✅ Loaded chip with the following chip_id: 1aab5941
# ✅ Loaded chip with the following chip_id: 1ac58eda
# ✅ Loaded chip with the following chip_id: 1acdf4b6
# ✅ Loaded chip with the following chip_id: 1ad89b8a
# ✅ Loaded chip with the following chip_id: 1adefc20
# ✅ Loaded chip with the following chip_id: 1aebea76
# ✅ Loaded chip with the following chip_id: 1af64c1a
# ✅ Loaded chip with the following chip_id: 1b1593e8
# ✅ Loaded chip with the following chip_id: 1b222645
# ✅ Loaded chip with the following chip_id: 1b35b32d
# ✅ Loaded chip with the following chip_id: 1b3c30c3
# ✅ Loaded chip with the following chip_id: 1b3d7911
# ✅ Loaded chip with the following chip_id: 1b3ede02
# ✅ Loaded chip with the following chip_id: 1b46e768
# ✅ Loaded chip with the following chip_id: 1b529f31
# ✅ Loaded chip with the following chip_id: 1b637aff
# ✅ Loaded chip with the following chip_id: 1b6d359c
# ✅ Loaded chip with the following chip_id: 1b6e62fd
# ✅ Loaded chip with the following chip_id: 1b7a76f8
# ✅ Loaded chip with the following chip_id: 1b82cc99
# ✅ Loaded chip with the following chip_id: 1b875bb0
# ✅ Loaded chip with the following chip_id: 1b8c97f8
# ✅ Loaded chip with the following chip_id: 1b8fc47d
# ✅ Loaded chip with the following chip_id: 1b9151ba
# ✅ Loaded chip with the following chip_id: 1b9366bb
# ✅ Loaded chip with the following chip_id: 1b940233
# ✅ Loaded chip with the following chip_id: 1b9a4249
# ✅ Loaded chip with the following chip_id: 1b9eb19c
# ✅ Loaded chip with the following chip_id: 1ba61dc5
# ✅ Loaded chip with the following chip_id: 1ba7050d
# ✅ Loaded chip with the following chip_id: 1bb91fe9
# ✅ Loaded chip with the following chip_id: 1bbb53f8
# ✅ Loaded chip with the following chip_id: 1bc0d9ae
# ✅ Loaded chip with the following chip_id: 1bcc6727
# ✅ Loaded chip with the following chip_id: 1bd00a0a
# ✅ Loaded chip with the following chip_id: 1bd0b18f
# ✅ Loaded chip with the following chip_id: 1bd3ee4a
# ✅ Loaded chip with the following chip_id: 1bd933c5
# ✅ Loaded chip with the following chip_id: 1bebc830
# ✅ Loaded chip with the following chip_id: 1bed1748
# ✅ Loaded chip with the following chip_id: 1bf613a4
# ✅ Loaded chip with the following chip_id: 1bffc196
# ✅ Loaded chip with the following chip_id: 1c04573f
# ✅ Loaded chip with the following chip_id: 1c148fd3
# ✅ Loaded chip with the following chip_id: 1c1b81c5
# ✅ Loaded chip with the following chip_id: 1c1d8121
# ✅ Loaded chip with the following chip_id: 1c28eda9
# ✅ Loaded chip with the following chip_id: 1c2a6886
# ✅ Loaded chip with the following chip_id: 1c2d43ef
# ✅ Loaded chip with the following chip_id: 1c312517
# ✅ Loaded chip with the following chip_id: 1c336d22
# ✅ Loaded chip with the following chip_id: 1c5787b1
# ✅ Loaded chip with the following chip_id: 1c736465
# ✅ Loaded chip with the following chip_id: 1c81862c
# ✅ Loaded chip with the following chip_id: 1c86e26b
# ✅ Loaded chip with the following chip_id: 1c9623a5
# ✅ Loaded chip with the following chip_id: 1ca90e13
# ✅ Loaded chip with the following chip_id: 1cb30c14
# ✅ Loaded chip with the following chip_id: 1cba4cb1
# ✅ Loaded chip with the following chip_id: 1cc02390
# ✅ Loaded chip with the following chip_id: 1cc6f00a
# ✅ Loaded chip with the following chip_id: 1cc6f78e
# ✅ Loaded chip with the following chip_id: 1cd4956a
# ✅ Loaded chip with the following chip_id: 1cd6323f
# ✅ Loaded chip with the following chip_id: 1cec2f2a
# ✅ Loaded chip with the following chip_id: 1cf21b01
# ✅ Loaded chip with the following chip_id: 1d09f0c5
# ✅ Loaded chip with the following chip_id: 1d0b56ee
# ✅ Loaded chip with the following chip_id: 1d0dea6d
# ✅ Loaded chip with the following chip_id: 1d14bdf1
# ✅ Loaded chip with the following chip_id: 1d1bc8a6
# ✅ Loaded chip with the following chip_id: 1d2d0900
# ✅ Loaded chip with the following chip_id: 1d2e7fe8
# ✅ Loaded chip with the following chip_id: 1d4a14a9
# ✅ Loaded chip with the following chip_id: 1d4b9701
# ✅ Loaded chip with the following chip_id: 1d67d611
# ✅ Loaded chip with the following chip_id: 1d6f0a50
# ✅ Loaded chip with the following chip_id: 1d7700eb
# ✅ Loaded chip with the following chip_id: 1d780d43
# ✅ Loaded chip with the following chip_id: 1d8197ac
# ✅ Loaded chip with the following chip_id: 1d894be4
# ✅ Loaded chip with the following chip_id: 1d91f6c0
# ✅ Loaded chip with the following chip_id: 1d98f768
# ✅ Loaded chip with the following chip_id: 1d9b9f68
# ✅ Loaded chip with the following chip_id: 1da8bab2
# ✅ Loaded chip with the following chip_id: 1dae5100
# ✅ Loaded chip with the following chip_id: 1dafc60e
# ✅ Loaded chip with the following chip_id: 1dbb1f3b
# ✅ Loaded chip with the following chip_id: 1dc17c6e
# ✅ Loaded chip with the following chip_id: 1dc400fb
# ✅ Loaded chip with the following chip_id: 1dd63a3c
# ✅ Loaded chip with the following chip_id: 1dd88b4d
# ✅ Loaded chip with the following chip_id: 1ddfcbf5
# ✅ Loaded chip with the following chip_id: 1df195ad
# ✅ Loaded chip with the following chip_id: 1df48338
# ✅ Loaded chip with the following chip_id: 1df672f8
# ✅ Loaded chip with the following chip_id: 1df6d645
# ✅ Loaded chip with the following chip_id: 1df8214b
# ✅ Loaded chip with the following chip_id: 1dfca7aa
# ✅ Loaded chip with the following chip_id: 1e09df9e
# ✅ Loaded chip with the following chip_id: 1e131583
# ✅ Loaded chip with the following chip_id: 1e22799e
# ✅ Loaded chip with the following chip_id: 1e2e0888
# ✅ Loaded chip with the following chip_id: 1e3ca03e
# ✅ Loaded chip with the following chip_id: 1e3ec866
# ✅ Loaded chip with the following chip_id: 1e4111fb
# ✅ Loaded chip with the following chip_id: 1e484125
# ✅ Loaded chip with the following chip_id: 1e48eed0
# ✅ Loaded chip with the following chip_id: 1e5c6d42
# ✅ Loaded chip with the following chip_id: 1e63615b
# ✅ Loaded chip with the following chip_id: 1e6e8b4e
# ✅ Loaded chip with the following chip_id: 1e7789ff
# ✅ Loaded chip with the following chip_id: 1e7a610e
# ✅ Loaded chip with the following chip_id: 1e80a4fe
# ✅ Loaded chip with the following chip_id: 1e846dae
# ✅ Loaded chip with the following chip_id: 1e9649f3
# ✅ Loaded chip with the following chip_id: 1e9c4780
# ✅ Loaded chip with the following chip_id: 1eaf2bf8
# ✅ Loaded chip with the following chip_id: 1eb353bb
# ✅ Loaded chip with the following chip_id: 1eba01c1
# ✅ Loaded chip with the following chip_id: 1ec2f8ed
# ✅ Loaded chip with the following chip_id: 1ec3d1e1
# ✅ Loaded chip with the following chip_id: 1ecb9142
# ✅ Loaded chip with the following chip_id: 1ecd8946
# ✅ Loaded chip with the following chip_id: 1ed5831c
# ✅ Loaded chip with the following chip_id: 1edd7e96
# ✅ Loaded chip with the following chip_id: 1ede41e2
# ✅ Loaded chip with the following chip_id: 1efd5999
# ✅ Loaded chip with the following chip_id: 1f01c926
# ✅ Loaded chip with the following chip_id: 1f121e14
# ✅ Loaded chip with the following chip_id: 1f133781
# CPU times: user 4.59 s, sys: 3.93 s, total: 8.52 s
# Wall time: 48.8 s

# %%
def normalize_features(
    features: np.ndarray,
    features_mean=np.array([]),
    features_std=np.array([]),
) -> np.ndarray:
    features_arr = (
        tf.transpose(
            np.array(features), 
            perm=(3, 0, 1, 2)
        )
        .numpy()
    )
    
    if not features_mean.any():
        features_mean = features_arr.mean(axis=(0, 1, 2), keepdims=True)
    if not features_std.any():
        features_std = features_arr.std(axis=(0, 1, 2), keepdims=True)

    features_normalized = (
        tf.transpose(
            (features_arr - features_mean) / features_std,
            perm=(1, 2, 3, 0)
        )
        .numpy()
        .astype(np.float32)
    )
    
    return (
        features_normalized,
        features_mean,
        features_std,
    )

features_normalized, features_mean, features_std = normalize_features(features)
# Out:
# 2023-01-23 14:16:16.944613: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 5767168000 exceeds 10% of free system memory.
# 2023-01-23 14:16:22.205488: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 5767168000 exceeds 10% of free system memory.

# %%
# dataset = tf.data.Dataset.from_tensor_slices((features, labels))
dataset = tf.data.Dataset.from_tensor_slices((features_normalized, labels))
print(dataset)
# Out:
# 2023-01-23 14:16:37.572572: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 2883584000 exceeds 10% of free system memory.
# <TensorSliceDataset element_spec=(TensorSpec(shape=(256, 256, 11), dtype=tf.float32, name=None), TensorSpec(shape=(256, 256), dtype=tf.float32, name=None))>

# %%
BATCH_SIZE = 10
BUFFER_SIZE = 1000

# train_batches = train_dataset.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
# train_batches = train_batches.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
# validation_batches = test_dataset.take(3000).batch(BATCH_SIZE)
# test_batches = test_dataset.skip(3000).take(669).batch(BATCH_SIZE)

train_batches = (
    dataset
    .take(CHIPS_TO_SELECT_CNT - BATCH_SIZE)
    .cache()
    .batch(BATCH_SIZE)
    .repeat()
    .prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
)
test_batches = (
    dataset
    .skip(CHIPS_TO_SELECT_CNT - BATCH_SIZE)
    .take(BATCH_SIZE)
    .batch(BATCH_SIZE)
)

# %%
print(train_batches)
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 11), dtype=tf.float32, name=None), TensorSpec(shape=(None, 256, 256), dtype=tf.float32, name=None))>

# %%
def display(display_list):
    plt.figure(figsize=(15, 15))

    title = ["Input Image", "True Mask", "Predicted Mask"]

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(
            tf.transpose(display_list[i], perm=(2, 0, 1)).numpy()[3] # third band
            if i == 0 else display_list[i]
        )
        plt.axis("off")
    plt.show()

sample_batch = next(iter(train_batches))
random_index = np.random.choice(sample_batch[0].shape[0])
sample_image, sample_mask = sample_batch[0][random_index], sample_batch[1][random_index]
display([sample_image, sample_mask])
# Out:
# 2023-01-23 14:16:42.445277: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 2883584000 exceeds 10% of free system memory.
# 2023-01-23 14:16:43.541235: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# ## Create model

# %%
def double_conv_block(x, n_filters):
    # Conv2D then ReLU activation
    x = layers.Conv2D(
        n_filters, 
        3, 
        padding="same", 
        activation="relu", 
        kernel_initializer="he_normal"
    )(x)
    
    # Conv2D then ReLU activation
    x = layers.Conv2D(
        n_filters, 
        3, 
        padding="same", 
        activation="relu", 
        kernel_initializer="he_normal"
    )(x)
    
    return x

# %%
def downsample_block(x, n_filters):
    f = double_conv_block(x, n_filters)
    p = layers.MaxPool2D(2)(f)
    p = layers.Dropout(0.3)(p)
    return f, p

# %%
def upsample_block(x, conv_features, n_filters):
    # upsample
    x = layers.Conv2DTranspose(
        n_filters, 
        3, 
        2, 
        padding="same"
    )(x)
    
    # concatenate
    x = layers.concatenate([x, conv_features])
    
    # dropout
    x = layers.Dropout(0.3)(x)
    
    # Conv2D twice with ReLU activation
    x = double_conv_block(x, n_filters)
    
    return x

# %%
def build_unet_model():
    # inputs
    inputs = layers.Input(shape=(256, 256, 11))

    # encoder: contracting path - downsample
    # 1 - downsample
    f1, p1 = downsample_block(inputs, 64)
    # 2 - downsample
    f2, p2 = downsample_block(p1, 128)
    # 3 - downsample
    f3, p3 = downsample_block(p2, 256)
    # 4 - downsample
    f4, p4 = downsample_block(p3, 512)

    # 5 - bottleneck
    bottleneck = double_conv_block(p4, 1024)

    # decoder: expanding path - upsample
    # 6 - upsample
    u6 = upsample_block(bottleneck, f4, 512)
    # 7 - upsample
    u7 = upsample_block(u6, f3, 256)
    # 8 - upsample
    u8 = upsample_block(u7, f2, 128)
    # 9 - upsample
    u9 = upsample_block(u8, f1, 64)

    # outputs
    # outputs = layers.Conv2D(256, 256, padding="same", activation="softmax")(u9)
    outputs = layers.Conv2D(1, 1, padding="same", activation="linear")(u9)

    # unet model with Keras Functional API
    unet_model = tf.keras.Model(inputs, outputs, name="U-Net")

    return unet_model

# %% [markdown]
# ## Train model

# %%
# compile model

unet_model = build_unet_model()

unet_model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    # loss="mse",
    # metrics="mse",
    
    loss="MeanSquaredError",
    metrics="RootMeanSquaredError",
)

# %%
# %%time

NUM_EPOCHS = 50
TRAIN_LENGTH = CHIPS_TO_SELECT_CNT - BATCH_SIZE
STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE
# VAL_SUBSPLITS = 5
# TEST_LENTH = info.splits["test"].num_examples
# VALIDATION_STEPS = TEST_LENTH // BATCH_SIZE // VAL_SUBSPLITS
VALIDATION_STEPS = 2

model_history = unet_model.fit(
    train_batches,
    epochs=NUM_EPOCHS,
    # steps_per_epoch=2,
    steps_per_epoch=STEPS_PER_EPOCH,
    # validation_steps=VALIDATION_STEPS,
    validation_data=test_batches,
    verbose=True,
)
# Out:
# Epoch 1/50
# 99/99 [==============================] - ETA: 0s - loss: 31857950.0000 - root_mean_squared_error: 5644.2847
# 2023-01-23 14:31:45.918059: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 2883584000 exceeds 10% of free system memory.
# 99/99 [==============================] - 906s 9s/step - loss: 31857950.0000 - root_mean_squared_error: 5644.2847 - val_loss: 10495.9434 - val_root_mean_squared_error: 102.4497
# Epoch 2/50
# 99/99 [==============================] - 901s 9s/step - loss: 7387.5132 - root_mean_squared_error: 85.9507 - val_loss: 5528.1509 - val_root_mean_squared_error: 74.3515
# Epoch 3/50
# 99/99 [==============================] - 902s 9s/step - loss: 4568.7568 - root_mean_squared_error: 67.5926 - val_loss: 4852.4688 - val_root_mean_squared_error: 69.6597
# Epoch 4/50
# 99/99 [==============================] - 902s 9s/step - loss: 4134.0137 - root_mean_squared_error: 64.2963 - val_loss: 4124.8535 - val_root_mean_squared_error: 64.2250
# Epoch 5/50
# 99/99 [==============================] - 903s 9s/step - loss: 3728.5979 - root_mean_squared_error: 61.0622 - val_loss: 3987.1360 - val_root_mean_squared_error: 63.1438
# Epoch 6/50
# 99/99 [==============================] - 903s 9s/step - loss: 3510.9253 - root_mean_squared_error: 59.2531 - val_loss: 4099.1099 - val_root_mean_squared_error: 64.0243
# Epoch 7/50
# 99/99 [==============================] - 918s 9s/step - loss: 3386.7346 - root_mean_squared_error: 58.1957 - val_loss: 3966.9048 - val_root_mean_squared_error: 62.9834
# Epoch 8/50
# 99/99 [==============================] - 932s 9s/step - loss: 3297.8958 - root_mean_squared_error: 57.4273 - val_loss: 3830.2480 - val_root_mean_squared_error: 61.8890
# Epoch 9/50
# 99/99 [==============================] - 933s 9s/step - loss: 3213.6753 - root_mean_squared_error: 56.6893 - val_loss: 3722.7434 - val_root_mean_squared_error: 61.0143
# Epoch 10/50
# 99/99 [==============================] - 918s 9s/step - loss: 3131.1743 - root_mean_squared_error: 55.9569 - val_loss: 3386.5234 - val_root_mean_squared_error: 58.1938
# Epoch 11/50
# 99/99 [==============================] - 904s 9s/step - loss: 3081.2600 - root_mean_squared_error: 55.5091 - val_loss: 3340.1536 - val_root_mean_squared_error: 57.7941
# Epoch 12/50
# 99/99 [==============================] - 905s 9s/step - loss: 3028.0222 - root_mean_squared_error: 55.0275 - val_loss: 3191.0400 - val_root_mean_squared_error: 56.4893
# Epoch 13/50
# 99/99 [==============================] - 905s 9s/step - loss: 2995.4282 - root_mean_squared_error: 54.7305 - val_loss: 3120.6243 - val_root_mean_squared_error: 55.8625
# Epoch 14/50
# 99/99 [==============================] - 905s 9s/step - loss: 2962.9192 - root_mean_squared_error: 54.4327 - val_loss: 3032.0347 - val_root_mean_squared_error: 55.0639
# Epoch 15/50
# 99/99 [==============================] - 906s 9s/step - loss: 2936.3064 - root_mean_squared_error: 54.1877 - val_loss: 2932.8833 - val_root_mean_squared_error: 54.1561
# Epoch 16/50
# 99/99 [==============================] - 904s 9s/step - loss: 2914.9670 - root_mean_squared_error: 53.9904 - val_loss: 2878.1846 - val_root_mean_squared_error: 53.6487
# Epoch 17/50
# 99/99 [==============================] - 905s 9s/step - loss: 2896.9368 - root_mean_squared_error: 53.8232 - val_loss: 2867.6052 - val_root_mean_squared_error: 53.5500
# Epoch 18/50
# 99/99 [==============================] - 904s 9s/step - loss: 2878.7983 - root_mean_squared_error: 53.6544 - val_loss: 2824.8481 - val_root_mean_squared_error: 53.1493
# Epoch 19/50
# 99/99 [==============================] - 905s 9s/step - loss: 2865.6907 - root_mean_squared_error: 53.5321 - val_loss: 2825.8132 - val_root_mean_squared_error: 53.1584
# Epoch 20/50
# 99/99 [==============================] - 905s 9s/step - loss: 2848.5103 - root_mean_squared_error: 53.3714 - val_loss: 2782.3711 - val_root_mean_squared_error: 52.7482
# Epoch 21/50
# 99/99 [==============================] - 905s 9s/step - loss: 2834.2625 - root_mean_squared_error: 53.2378 - val_loss: 2766.7952 - val_root_mean_squared_error: 52.6003
# Epoch 22/50
# 99/99 [==============================] - 904s 9s/step - loss: 2819.9631 - root_mean_squared_error: 53.1033 - val_loss: 2724.8435 - val_root_mean_squared_error: 52.2000
# Epoch 23/50
# 99/99 [==============================] - 903s 9s/step - loss: 2807.3755 - root_mean_squared_error: 52.9847 - val_loss: 2706.1553 - val_root_mean_squared_error: 52.0207
# Epoch 24/50
# 99/99 [==============================] - 905s 9s/step - loss: 2792.1367 - root_mean_squared_error: 52.8407 - val_loss: 2669.1067 - val_root_mean_squared_error: 51.6634
# Epoch 25/50
# 99/99 [==============================] - 906s 9s/step - loss: 2786.0012 - root_mean_squared_error: 52.7826 - val_loss: 2632.8069 - val_root_mean_squared_error: 51.3109
# Epoch 26/50
# 99/99 [==============================] - 906s 9s/step - loss: 2773.2913 - root_mean_squared_error: 52.6620 - val_loss: 2617.7327 - val_root_mean_squared_error: 51.1638
# Epoch 27/50
# 99/99 [==============================] - 906s 9s/step - loss: 2761.1179 - root_mean_squared_error: 52.5463 - val_loss: 2599.0049 - val_root_mean_squared_error: 50.9804
# Epoch 28/50
# 99/99 [==============================] - 904s 9s/step - loss: 2744.9971 - root_mean_squared_error: 52.3927 - val_loss: 2562.9727 - val_root_mean_squared_error: 50.6258
# Epoch 29/50
# 99/99 [==============================] - 905s 9s/step - loss: 2727.0156 - root_mean_squared_error: 52.2208 - val_loss: 2536.7383 - val_root_mean_squared_error: 50.3660
# Epoch 30/50
# 99/99 [==============================] - 904s 9s/step - loss: 2717.0476 - root_mean_squared_error: 52.1253 - val_loss: 2552.8716 - val_root_mean_squared_error: 50.5259
# Epoch 31/50
# 99/99 [==============================] - 904s 9s/step - loss: 2706.2681 - root_mean_squared_error: 52.0218 - val_loss: 2516.4766 - val_root_mean_squared_error: 50.1645
# Epoch 32/50
# 99/99 [==============================] - 905s 9s/step - loss: 2700.5403 - root_mean_squared_error: 51.9667 - val_loss: 2498.9241 - val_root_mean_squared_error: 49.9892
# Epoch 33/50
# 99/99 [==============================] - 905s 9s/step - loss: 2688.6401 - root_mean_squared_error: 51.8521 - val_loss: 2543.9136 - val_root_mean_squared_error: 50.4372
# Epoch 34/50
# 99/99 [==============================] - 906s 9s/step - loss: 2670.3394 - root_mean_squared_error: 51.6753 - val_loss: 2476.4504 - val_root_mean_squared_error: 49.7639
# Epoch 35/50
# 99/99 [==============================] - 906s 9s/step - loss: 2657.0615 - root_mean_squared_error: 51.5467 - val_loss: 2454.6228 - val_root_mean_squared_error: 49.5442
# Epoch 36/50
# 99/99 [==============================] - 905s 9s/step - loss: 2646.4294 - root_mean_squared_error: 51.4435 - val_loss: 2420.9106 - val_root_mean_squared_error: 49.2028
# Epoch 37/50
# 99/99 [==============================] - 904s 9s/step - loss: 2637.7883 - root_mean_squared_error: 51.3594 - val_loss: 2428.7312 - val_root_mean_squared_error: 49.2822
# Epoch 38/50
# 99/99 [==============================] - 906s 9s/step - loss: 2627.8918 - root_mean_squared_error: 51.2630 - val_loss: 2406.2009 - val_root_mean_squared_error: 49.0530
# Epoch 39/50
# 99/99 [==============================] - 905s 9s/step - loss: 2620.6621 - root_mean_squared_error: 51.1924 - val_loss: 2433.3098 - val_root_mean_squared_error: 49.3286
# Epoch 40/50
# 99/99 [==============================] - 905s 9s/step - loss: 2614.8433 - root_mean_squared_error: 51.1355 - val_loss: 2428.9460 - val_root_mean_squared_error: 49.2843
# Epoch 41/50
# 99/99 [==============================] - 904s 9s/step - loss: 2601.7283 - root_mean_squared_error: 51.0071 - val_loss: 2385.9685 - val_root_mean_squared_error: 48.8464
# Epoch 42/50
# 99/99 [==============================] - 905s 9s/step - loss: 2592.6101 - root_mean_squared_error: 50.9177 - val_loss: 2377.7290 - val_root_mean_squared_error: 48.7620
# Epoch 43/50
# 99/99 [==============================] - 906s 9s/step - loss: 2589.5786 - root_mean_squared_error: 50.8879 - val_loss: 2387.3022 - val_root_mean_squared_error: 48.8600
# Epoch 44/50
# 99/99 [==============================] - 905s 9s/step - loss: 2579.3257 - root_mean_squared_error: 50.7871 - val_loss: 2361.4395 - val_root_mean_squared_error: 48.5946
# Epoch 45/50
# 99/99 [==============================] - 906s 9s/step - loss: 2585.4136 - root_mean_squared_error: 50.8470 - val_loss: 2391.1167 - val_root_mean_squared_error: 48.8990
# Epoch 46/50
# 99/99 [==============================] - 905s 9s/step - loss: 2583.3535 - root_mean_squared_error: 50.8267 - val_loss: 2342.7571 - val_root_mean_squared_error: 48.4020
# Epoch 47/50
# 99/99 [==============================] - 906s 9s/step - loss: 2559.4810 - root_mean_squared_error: 50.5913 - val_loss: 2339.1062 - val_root_mean_squared_error: 48.3643
# Epoch 48/50
# 99/99 [==============================] - 905s 9s/step - loss: 2564.5779 - root_mean_squared_error: 50.6417 - val_loss: 2382.9695 - val_root_mean_squared_error: 48.8157
# Epoch 49/50
# 99/99 [==============================] - 905s 9s/step - loss: 2550.0681 - root_mean_squared_error: 50.4982 - val_loss: 2356.7632 - val_root_mean_squared_error: 48.5465
# Epoch 50/50
# 99/99 [==============================] - 906s 9s/step - loss: 2556.3062 - root_mean_squared_error: 50.5599 - val_loss: 2394.6426 - val_root_mean_squared_error: 48.9351
# CPU times: user 3d 18h 34min 38s, sys: 4h 56min 35s, total: 3d 23h 31min 13s
# Wall time: 12h 35min 21s

# %% [markdown]
# ## Check model results

# %%
ax = (
    pd.DataFrame({
        # "loss": model_history.history["loss"],
        # "val_loss": model_history.history["val_loss"], 
        "RMSE (train)": model_history.history["root_mean_squared_error"][7:],
        "RMSE (val)": model_history.history["val_root_mean_squared_error"][7:],
    })
    .plot(
        title="U-Net learning progress"
    )
)

ax.set_xlabel("Epoch")
ax.set_ylabel("RMSE")

plt.show()

# %%
test_results = unet_model.predict(
    test_batches
)

for res in test_results:
    plt.imshow(res)
    plt.show()
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
sample_batch = next(iter(test_batches))
random_index = np.random.choice(sample_batch[0].shape[0])
sample_image, sample_mask = sample_batch[0][random_index], sample_batch[1][random_index]
display([sample_image, sample_mask])

# %% [markdown]
# ## Create submission

# %%
df_metadata = pd.read_csv(FEATURES_METADATA_PROCESSED_FILEPATH)

# filter metadata
df_metadata = (
    df_metadata
    .loc[
        (df_metadata.month == "April") &
        (df_metadata.satellite == "S2") &
        (df_metadata.split == "test")
    ]
    .reset_index(drop=True)
)

# df_metadata["satellite_cnt_per_chip_month"] = (
#     df_metadata
#     .groupby(["chip_id", "month"])
#     .satellite
#     .transform("count")
# )

df_metadata.tail()
# Out:
#                 filename                                           filepath  \
# 2768  ff9dfc68_S2_07.tif  /usr/src/app/data/test_features/ff9dfc68_S2_07...
# 2769  ffda6cc9_S2_07.tif  /usr/src/app/data/test_features/ffda6cc9_S2_07...
# 2770  ffde1ed8_S2_07.tif  /usr/src/app/data/test_features/ffde1ed8_S2_07...
# 2771  ffdfa26a_S2_07.tif  /usr/src/app/data/test_features/ffdfa26a_S2_07...
# 2772  fff812c0_S2_07.tif  /usr/src/app/data/test_features/fff812c0_S2_07...
#
#          label_filename                                 label_filepath  \
# 2768  ff9dfc68_agbm.tif  /usr/src/app/data/test_agbm/ff9dfc68_agbm.tif
# 2769  ffda6cc9_agbm.tif  /usr/src/app/data/test_agbm/ffda6cc9_agbm.tif
# 2770  ffde1ed8_agbm.tif  /usr/src/app/data/test_agbm/ffde1ed8_agbm.tif
# 2771  ffdfa26a_agbm.tif  /usr/src/app/data/test_agbm/ffdfa26a_agbm.tif
# 2772  fff812c0_agbm.tif  /usr/src/app/data/test_agbm/fff812c0_agbm.tif
#
#        chip_id satellite split  month
# 2768  ff9dfc68        S2  test  April
# 2769  ffda6cc9        S2  test  April
# 2770  ffde1ed8        S2  test  April
# 2771  ffdfa26a        S2  test  April
# 2772  fff812c0        S2  test  April

# %%
# %%time

# predictions mean

for i, row in df_metadata.iterrows():
    
    # read filepath and label filepath
    filepath = row["filepath"]
    label_filepath = row["label_filepath"]
    
    img = tiff.imread(filepath)
    img_norm, _, _ = normalize_features([img], features_mean, features_std)
    pred = unet_model.predict(
        # img.reshape(1, 256, 256, 11),
        img_norm,
        verbose=False,
    )
    
    # save predictions
    tiff.imwrite(
        label_filepath, 
        data=(
            pred[0]
            .reshape(256, 256)
            .astype(np.float32) 
        )
    )
    
    if (i % 100 == 0) & (i != 0):
        print(f"--> finished prediciton of {i:,} tifs")
# Out:
# --> finished prediciton of 100 tifs
# --> finished prediciton of 200 tifs
# --> finished prediciton of 300 tifs
# --> finished prediciton of 400 tifs
# --> finished prediciton of 500 tifs
# --> finished prediciton of 600 tifs
# --> finished prediciton of 700 tifs
# --> finished prediciton of 800 tifs
# --> finished prediciton of 900 tifs
# --> finished prediciton of 1,000 tifs
# --> finished prediciton of 1,100 tifs
# --> finished prediciton of 1,200 tifs
# --> finished prediciton of 1,300 tifs
# --> finished prediciton of 1,400 tifs
# --> finished prediciton of 1,500 tifs
# --> finished prediciton of 1,600 tifs
# --> finished prediciton of 1,700 tifs
# --> finished prediciton of 1,800 tifs
# --> finished prediciton of 1,900 tifs
# --> finished prediciton of 2,000 tifs
# --> finished prediciton of 2,100 tifs
# --> finished prediciton of 2,200 tifs
# --> finished prediciton of 2,300 tifs
# --> finished prediciton of 2,400 tifs
# --> finished prediciton of 2,500 tifs
# --> finished prediciton of 2,600 tifs
# --> finished prediciton of 2,700 tifs
# CPU times: user 1h 35min 57s, sys: 2min 54s, total: 1h 38min 51s
# Wall time: 17min 35s

# %% [markdown]
# ## Results
#
# - The following submissions have been made.
#     - Model 8 (U-net v1)
#         - Model has been trained on data subset (1 month, 90 chips per month).
#         - Model has been tested on 10 chips.
#         - Average RMSE equal to 58.5.
#     - Model 9 (U-net without clouds)
#         - Model has been trained on data subset (1 month, 90 chips per month).
#         - Model has been tested on 10 chips.
#         - Average RMSE equal to 61.8.
#     - Model 10 (U-net with clouds, the same chips as Model 9)
#         - Model has been trained on data subset (1 month, 90 chips per month).
#         - Model has been tested on 10 chips.
#         - Average RMSE equal to 56.1.
#     - Model 11 (U-net with clouds, the same chips as Model 9, normalized, 20 epochs)
#         - Model has been trained on data subset (1 month, 90 chips per month).
#         - Model has been tested on 10 chips.
#         - Average RMSE equal to 74.9.
#     - Model 12 (U-net with clouds, the same chips as Model 9, normalized, 50 epochs)
#         - Model has been trained on data subset (1 month, 90 chips per month).
#         - Model has been tested on 10 chips.
#         - Average RMSE equal to 53.7.
#     - Model 13 (U-net with clouds, the same chips as Model 9, normalized, 50 epochs)
#         - Model has been trained on data subset (1 month, 990 chips per month).
#         - Model has been tested on 10 chips.
#         - Average RMSE equal to 45.3.
#
# *Yes, the results don't make very much the sense.*
